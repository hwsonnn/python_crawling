# %%
frame_lvl_record = "C:/Users/jsdata/Desktop/python/kaggle 3rd youtube/frame/frame.train00.tfrecord"

# %%
frame_lvl_record
# Out:
# 'C:/Users/jsdata/Desktop/python/kaggle 3rd youtube/frame/frame.train00.tfrecord'

# %%
import os

# %%
print(os.listdir("C:/Users/jsdata/Desktop/python/kaggle 3rd youtube/frame"))
print(os.listdir("C:/Users/jsdata/Desktop/python/kaggle 3rd youtube/validate"))
# Out:
# ['train00.tfrecord', 'train01.tfrecord']
# ['validate00.tfrecord', 'validate01.tfrecord']

# %%
import numpy as np
import pandas as pd

from IPython.display import YouTubeVideo

# %%
import tensorflow as tf
# 텐서플로는 구글에서 만든 딥러닝 프로그램을 쉽게 구현할 수 있도록 다양한 기능을 제공해주는 라이브러리다.

# in the prompt, 
# 1. conda update -n base conda
# 2. conda update --all
# 3. pip install tensorflow

# %%
vid_ids = []
labels = []

for example in tf.python_io.tf_record_iterator(frame_lvl_record):
    tf_example = tf.train.Example.FromString(example)
    vid_ids.append(tf_example.features.feature['id']
                   .bytes_list.value[0].decode(encoding='UTF-8'))
    labels.append(tf_example.features.feature['labels'].int64_list.value)
# Out:
# WARNING:tensorflow:From <ipython-input-7-5a77d93957a5>:4: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
vid_ids = []
for example in tf.python_io.tf_record_iterator(frame_lvl_record):
    tf_example = tf.train.Example.FromString(example)
    vid_ids.append(tf_example.features.feature['id']).bytes_list.value[0].decode(encoding='UTF-8')

# %%
labels = []
for example in tf.python_io.tf_record_iterator(frame_lvl_record):
    labels.append(tf_example.features.feature['labes'].int64_list.value)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 330

# %%
print('Number of videos in this tfrecord: ',len(vid_ids))
print('Picking a youtube video id:',vid_ids[13])
# Out:
# Number of videos in this tfrecord:  0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-d8c1096c69b9> in <module>
#       1 print('Number of videos in this tfrecord: ',len(vid_ids))
# ----> 2 print('Picking a youtube video id:',vid_ids[13])
#
# IndexError: list index out of range
# ERROR! Session/line number was not unique in database. History logging moved to new session 328

# %%
YouTubeVideo('UzXQaOLQVCU')

# %%
print('The first video has %d frames' %len(feat_rgb[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-91bbda763893> in <module>
# ----> 1 print('The first video has %d frames' %len(feat_rgb[0]))
#
# NameError: name 'feat_rgb' is not defined
