# %%
from konlpy.tag import *
import time

# %% [markdown]
# ### 오픈소스 형식 형태소 분석기 5가지
# - mecab 확인하고 다시.. 우분투가 잘안되서 패스
# - 한나눔은 너무 성능이 떨어져서 제외. 일단표기는 해둠
# - 카카오 형태소 분석기 카이를 제외한 이유는 사전 추가가 안된다.
#
# - 트위터 분석기, 코모란 두 가지를 중점

# %%
okt = Okt()
han = Hannanum()
komoran = Komoran()
ko = Kkma()

# %%
# 데이터 입수
text = open( 'NCS 크릴오일.txt' ).read()

# %% [markdown]
# #### 트위터 부분

# %%
# 트위터 morphs
okt_result = okt.morphs(text)
# 트위터 nouns 
okt_result1 = okt.nouns(text)
# 트위터 phrases
okt_result2 = okt.phrases(text)
# 트위터 pos 
okt_result3 = okt.pos(text)

# %%
# 트위터 분석기 
print(okt_result3)
# Out:
# [('크릴', 'Noun'), ('오일', 'Noun'), ('에', 'Josa'), ('대한', 'Noun'), ('최근', 'Noun'), ('의', 'Josa'), ('논문', 'Noun'), ('을', 'Josa'), ('좀', 'Noun'), ('보고싶었다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('퇴근', 'Noun'), ('길', 'Noun'), ('에', 'Josa'), ('스마트폰', 'Noun'), ('으로', 'Josa'), ('좀', 'Noun'), ('찾아본', 'Verb'), ('크릴', 'Noun'), ('오일', 'Noun'), ('논문', 'Noun'), ('.', 'Punctuation'), ('(', 'Punctuation'), ('아주', 'Noun'), ('핸드폰', 'Noun'), ('용량', 'Noun'), ('이', 'Josa'), ('터진다', 'Verb'), ('..', 'Punctuation'), ('요즘', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('?', 'Punctuation'), ('\n', 'Foreign'), ('그냥', 'Noun'), ('scholar', 'Alpha'), ('google', 'Alpha'), ('에서', 'Josa'), ('krill', 'Alpha'), ('oil', 'Alpha'), ('로', 'Noun'), ('검색', 'Noun'), ('하고', 'Josa'), (',', 'Punctuation'), ('기간', 'Noun'), ('은', 'Josa'), ('2019년', 'Number'), ('으로', 'Foreign'), ('지정', 'Noun'), ('해서', 'Verb'), ('제일', 'Noun'), ('최근', 'Noun'), ('의', 'Josa'), ('논문', 'Noun'), ('을', 'Josa'), ('검색', 'Noun'), ('한', 'Josa'), ('다음', 'Noun'), ('뭐', 'Noun'), ('돈', 'Noun'), ('내고', 'Verb'), ('논문', 'Noun'), ('볼', 'Noun'), ('그런건', 'Adjective'), ('아니니자', 'Adjective'), ('\n', 'Foreign'), ('open', 'Alpha'), ('acess', 'Alpha'), ('를', 'Noun'), ('확인', 'Noun'), ('\n', 'Foreign'), ('마침', 'Noun'), ('"', 'Punctuation'), ('COMPREHENSIVE', 'Alpha'), ('REVIEWS', 'Alpha'), ('IN', 'Alpha'), ('FOOD', 'Alpha'), ('SCIENCE', 'Alpha'), ('AND', 'Alpha'), ('FOOD', 'Alpha'), ('SAFETY', 'Alpha'), ('"', 'Punctuation'), ('라고', 'Josa'), ('SCIE', 'Alpha'), ('급', 'Noun'), ('의', 'Josa'), ('저', 'Determiner'), ('널', 'Noun'), ('에서', 'Josa'), ('나온', 'Verb'), ('리뷰', 'Noun'), ('논문', 'Noun'), ('이', 'Josa'), ('있어서', 'Adjective'), ('읽어', 'Verb'), ('보기', 'Noun'), ('로', 'Josa'), ('함', 'Noun'), ('IF', 'Alpha'), ('7', 'Number'), ('점', 'Noun'), ('정도', 'Noun'), ('면', 'Josa'), ('수준', 'Noun'), ('은', 'Josa'), ('나쁘지', 'Adjective'), ('않은', 'Verb'), ('저', 'Determiner'), ('널', 'Noun'), ('크릴', 'Noun'), ('오일', 'Noun'), ('의', 'Josa'), ('구성', 'Noun'), ('성분', 'Noun'), (',', 'Punctuation'), ('추출', 'Noun'), ('기법', 'Noun'), (',', 'Punctuation'), ('기능', 'Noun'), ('성', 'Suffix'), ('및', 'Noun'), ('최근', 'Noun'), ('이슈', 'Noun'), ('들', 'Suffix'), ('에', 'Josa'), ('대한', 'Noun'), ('종합', 'Noun'), ('적', 'Suffix'), ('검토', 'Noun'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('좋은', 'Adjective'), ('내', 'Determiner'), ('용이', 'Noun'), ('겠고', 'Verb'), (',', 'Punctuation'), ('길겠구나', 'Adjective'), ('..', 'Punctuation'), ('ㅜㅜ', 'KoreanParticle'), ('\n', 'Foreign'), ('?', 'Punctuation'), ('대충', 'Noun'), ('보고', 'Noun'), ('보고', 'Noun'), ('싶은', 'Verb'), ('부분', 'Noun'), ('들', 'Suffix'), ('만', 'Josa'), ('보자면', 'Verb'), (',', 'Punctuation'), ('크릴', 'Noun'), ('오일', 'Noun'), ('은', 'Josa'), ('2009년', 'Number'), ('미국', 'Noun'), ('에서', 'Josa'), ('GRAS', 'Alpha'), ('에', 'Josa'), ('등재', 'Noun'), ('되었고', 'Verb'), ('유럽', 'Noun'), ('에서는', 'Josa'), ('2009년', 'Number'), ('Novel', 'Alpha'), ('food', 'Alpha'), ('로', 'Noun'), ('인정받았고', 'Verb'), ('\n', 'Foreign'), ('중국', 'Noun'), ('에서는', 'Josa'), ('2014년', 'Number'), ('에', 'Foreign'), ('식품', 'Noun'), ('으로', 'Josa'), ('허용', 'Noun'), ('되었으며', 'Verb'), (',', 'Punctuation'), ('최근', 'Noun'), ('에는', 'Josa'), ('유럽', 'Noun'), ('에서는', 'Josa'), ('임신', 'Noun'), ('중이', 'Noun'), ('거나', 'Noun'), ('수유', 'Noun'), ('중', 'Noun'), ('에도', 'Josa'), ('먹을', 'Verb'), ('수', 'Noun'), ('있다고', 'Adjective'), ('결정', 'Noun'), ('하였음', 'Verb'), ('.', 'Punctuation'), ('최근', 'Noun'), ('에서야', 'Josa'), ('사람', 'Noun'), ('이', 'Josa'), ('먹기', 'Noun'), ('로', 'Josa'), ('하였으나', 'Verb'), (',', 'Punctuation'), ('굉장히', 'Adjective'), ('안전한', 'Adjective'), ('편이', 'Noun'), ('라는', 'Josa'), ('것', 'Noun'), ('.', 'Punctuation'), ('?', 'Punctuation'), ('크릴', 'Noun'), ('은', 'Josa'), ('다양한', 'Adjective'), ('지질', 'Noun'), ('성분', 'Noun'), ('프로파일', 'Noun'), ('을', 'Josa'), ('보이는데', 'Verb'), (',', 'Punctuation'), ('계절', 'Noun'), ('적', 'Suffix'), ('변화', 'Noun'), (',', 'Punctuation'), ('연중', 'Noun'), ('환경', 'Noun'), ('변화', 'Noun'), (',', 'Punctuation'), ('포획', 'Noun'), ('된', 'Verb'), ('크릴 ...

# %% [markdown]
# ### 코모란 부분

# %%
komoran_result = komoran.nouns("\n".join([x for x in text.split("\n") if x]))
komoran_result1 = komoran.morphs("\n".join([x for x in text.split("\n") if x]))
komoran_result2 = komoran.pos("\n".join([x for x in text.split("\n") if x]))

# %%
# 코모란 
komoran_result2
# Out:
# [('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('에', 'JKB'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('최근', 'NNG'),
#  ('의', 'JKG'),
#  ('논문', 'NNG'),
#  ('을', 'JKO'),
#  ('좀', 'MAG'),
#  ('보', 'VV'),
#  ('고', 'EC'),
#  ('싶', 'VX'),
#  ('었', 'EP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('퇴근', 'NNG'),
#  ('길', 'NNG'),
#  ('에', 'JKB'),
#  ('스마트폰', 'NNP'),
#  ('으로', 'JKB'),
#  ('좀', 'MAG'),
#  ('찾아보', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('논문', 'NNP'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('아주', 'NNP'),
#  ('핸드폰', 'NNP'),
#  ('용량', 'NNP'),
#  ('이', 'JKS'),
#  ('터지', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('.', 'SF'),
#  ('요즘', 'NNG'),
#  (')', 'SS'),
#  ('?', 'SF'),
#  ('그냥', 'MAG'),
#  ('scholar', 'SL'),
#  ('google', 'SL'),
#  ('에서', 'JKB'),
#  ('krill', 'SL'),
#  ('oil', 'SL'),
#  ('로', 'JKB'),
#  ('검색', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('기간', 'NNG'),
#  ('은', 'JX'),
#  ('2019', 'SN'),
#  ('년', 'NNB'),
#  ('으로', 'JKB'),
#  ('지정', 'NNG'),
#  ('하', 'XSV'),
#  ('아서', 'EC'),
#  ('제일', 'NNG'),
#  ('최근', 'NNG'),
#  ('의', 'JKG'),
#  ('논문', 'NNG'),
#  ('을', 'JKO'),
#  ('검색', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('다음', 'NNG'),
#  ('뭐', 'NP'),
#  ('돈', 'NNG'),
#  ('내', 'VV'),
#  ('고', 'EC'),
#  ('논문', 'NNP'),
#  ('보', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('그런', 'MM'),
#  ('건', 'NNB'),
#  ('아니', 'VCN'),
#  ('니', 'EC'),
#  ('자', 'VV'),
#  ('아', 'EC'),
#  ('open', 'SL'),
#  ('acess', 'SL'),
#  ('를', 'JKO'),
#  ('확인', 'NNG'),
#  ('마침', 'MAG'),
#  ('"', 'SS'),
#  ('COMPREHENSIVE', 'SL'),
#  ('REVIEWS', 'SL'),
#  ('IN', 'SL'),
#  ('FOOD', 'SL'),
#  ('SCIENCE', 'SL'),
#  ('AND', 'SL'),
#  ('FOOD', 'SL'),
#  ('SAFETY', 'SL'),
#  ('"', 'SS'),
#  ('라고', 'JKQ'),
#  ('SCIE', 'SL'),
#  ('급', 'NNG'),
#  ('의', 'JKG'),
#  ('저널', 'NNP'),
#  ('에서', 'JKB'),
#  ('나오', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('리뷰', 'NNP'),
#  ('논문', 'NNP'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('어서', 'EC'),
#  ('읽', 'VV'),
#  ('어', 'EC'),
#  ('보', 'VX'),
#  ('기', 'ETN'),
#  ('로', 'JKB'),
#  ('하', 'VV'),
#  ('ㅁ', 'ETN'),
#  ('IF', 'SL'),
#  ('7', 'SN'),
#  ('점', 'NNB'),
#  ('정도', 'NNG'),
#  ('이', 'VCP'),
#  ('면', 'EC'),
#  ('수준', 'NNG'),
#  ('은', 'JX'),
#  ('나쁘', 'VA'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('은', 'ETM'),
#  ('저널', 'NNP'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('의', 'JKG'),
#  ('구성', 'NNG'),
#  ('성분', 'NNG'),
#  (',', 'SP'),
#  ('추출', 'NNP'),
#  ('기법', 'NNG'),
#  (',', 'SP'),
#  ('기능', 'NNG'),
#  ('성', 'XSN'),
#  ('및', 'MAJ'),
#  ('최근', 'NNG'),
#  ('이슈', 'NNG'),
#  ('들', 'XSN'),
#  ('에', 'JKB'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('종합', 'NNG'),
#  ('적', 'XSN'),
#  ('검토', 'NNG'),
#  ('.', 'SF'),
#  ('좋', 'VA'),
#  ('은', 'ETM'),
#  ('내용', 'NNG'),
#  ('이', 'VCP'),
#  ('겠', 'EP'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('길', 'VA'),
#  ('겠', 'EP'),
#  ('구나', 'EF'),
#  ('.', 'SF'),
#  ('.', 'SF'),
#  ('ㅜㅜ', 'NA'),
#  ('?', 'SF'),
#  ('대충', 'NNP'),
#  ('보고', 'JKB'),
#  ('보', 'VV'),
#  ('고', 'EC'),
#  ('싶', 'VX'),
#  ('은', 'ETM'),
#  ('부분', 'NNG'),
#  ('들', 'XSN'),
#  ('만', 'JX'),
#  ('보', 'VV'),
#  ('자면', 'EC'),
#  (',', 'SP'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('은', 'JX'),
#  ('2009', 'SN'),
#  ('년', 'NNB'),
#  ('미국', 'NNP'),
#  ('에서', 'JKB'),
#  ('GRAS', 'SL'),
#  ('에', 'JKB'),
#  ('등재', 'NNG'),
#  ('되', 'XSV'),
#  ('었', 'EP'),
#  ('고', 'EC'),
#  ('유럽', 'NNP'),
#  ('에서', 'JKB'),
#  ('는', 'JX'),
#  ('2009', 'SN'),
#  ('년', 'NNB'),
#  ('Novel', 'SL'),
#  ('food', 'SL'),
#  ('로', 'JKB'),
#  ('인정받', 'VV'),
#  ('았', 'EP'),
#  ('고', 'EC'),
#  ('중국', 'NNP'),
#  ('에서', 'JKB'),
#  ('는', 'JX'),
#  ('2014', 'SN'),
#  ('년', 'NNB'),
#  ('에', 'JKB'),
#  ('식품', 'NNG'),
#  ('으로', 'JKB'),
#  ('허용', 'NNG'),
#  ('되', 'XSV'),
#  ('었', 'EP'),
#  ('으며', 'EC'),
#  (',', 'SP'),
#  ('최근', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('유럽', 'NNP'),
#  ('에서', 'JKB'),
#  ('는', 'JX'),
#  ('임신', 'NNP'),
#  ('중', 'NNB'),
#  ('이', 'VCP'),
#  ('거나', 'EC'),
#  ('수유', 'NNP'),
#  ('중', 'NNB'),
#  ('에', 'JKB'),
#  ('도', 'JX'),
#  ('먹', 'VV'),
#  ('을', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('다고', 'EC'),
#  ('결정', 'NNG'),
#  ('하', 'XSV'),
#  ('았', 'EP'),
#  ('음', 'ETN'),
#  ('.', 'SF'),
#  ('최근', 'NNG'),
#  ('에서', 'JKB'),
#  ('야', 'JX'),
#  ('사람', 'NNG'),
#  ('이', 'JKS'),
#  ('먹', 'VV'),
#  ('기', 'ETN'),
#  ('로', 'JKB'),
#  ('하', 'VV'),
#  ('았', 'EP'),
#  ('으나', 'EC'),
#  (',', 'SP'),
#  ('굉장히', 'MAG'),
#  ('안전', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('편', 'NNB'),
#  ('이', 'VCP'),
#  ('라는', 'ETM'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('?', 'SF'),
#  ('크릴', 'NNP'),
#  ('은', 'JX'),
#  ('다양', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('지질', 'NNP'),
#  ('성분', 'NNG'),
#  ('프로파일', 'NNP'),
#  ('을', 'JKO'),
#  ('보이', 'VV'),
#  ('는데', 'EC'),
#  (',', 'SP'),
#  ('계절', 'NNG'),
#  ('적', 'XSN'),
#  ('변화', 'NNG'),
#  (',', 'SP'),
#  ('연중', 'NNG'),
#  ('환경', 'NNG'),
#  ('변화', 'NNG'),
#  (',', 'SP'),
#  ('포획', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('크릴', 'NNP'),
#  ('의', 'JKG'),
#  ('생육', 'NNG'),
#  ('정도', 'NNG'),
#  (',', 'SP'),
#  ('저장', 'NNG'),
#  ('조건', 'NNG'),
#  (',', 'SP'),
#  ('운송', 'NNP'),
#  ('조건', 'NNG'),
#  (',', 'SP'),
#  ('원료', 'NNG'),
#  ('의', 'JKG'),
#  ('전', 'MM'),
#  ('처리', 'NNP'),
#  ('방법', 'NNG'),
#  ('및', 'MAJ'),
#  ('공정', 'NNG'),
#  ('에', 'JKB'),
#  ('따르', 'VV'),
#  ('아', 'EC'),
#  ('지질', 'NNP'),
#  ('의', 'JKG'),
#  ('조성', 'NNG'),
#  ('이', 'JKS'),
#  ('달라지', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('예', 'NNG'),
#  ('를', 'JKO'),
#  ('들', 'VV'),
#  ('어', 'EC'),
#  (',', 'SP'),
#  ('고온', 'NNG'),
#  ('에서', 'JKB'),
#  ('탈수', 'NNP'),
#  ('(', 'SS'),
#  ('dehydration', 'SL'),
#  (')', 'SS'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('경우', 'NNG'),
#  ('고온', 'NNG'),
#  ('에서', 'JKB'),
#  ('지질', 'NNP'),
#  ('의', 'JKG'),
#  ('가수', 'NNG'),
#  ('분해', 'NNG'),
#  ('가', 'JKS'),
#  ('유발', 'NNG'),
#  ('되', 'XSV'),
#  ('므로', 'EC'),
#  ('동결', 'NNG'),
#  ('건조', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('크릴', 'NNP'),
#  ('에', 'JKB'),
#  ('비하', 'VV'),
#  ('아', 'EC'),
#  ('유리', 'NNP'),
#  ('지방산', 'NNP'),
#  ('(', 'SS'),
#  ('FFA', 'SL'),
#  (')', 'SS'),
#  ('이', 'MM'),
#  ('더', 'MAG'),
#  ('많이', 'MAG'),
#  ('생성', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('히익..', 'NA'),
#  ('유리', 'NNP'),
#  ('지방산', 'NNP'),
#  ('...', 'SE'),
#  ('ㄷㄷㄷ', 'NA'),
#  ('중년', 'NNP'),
#  ('남성', 'NNG'),
#  ('의', 'JKG'),
#  ('돌연사', 'NNP'),
#  ('위험', 'NNP'),
#  ('인자', 'NNP'),
#  ('이', 'VCP'),
#  ('기', 'ETN'),
#  ('도', 'JX'),
#  ('하', 'VX'),
#  ('지', 'EF'),
#  ('.', 'SF'),
#  ('.', 'SF'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('동결', 'NNG'),
#  ('.', 'SF'),
#  ('.', 'SF'),
#  ('이것', 'NP'),
#  ('중요', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('듯', 'NNB'),
#  ('.', 'SF'),
#  ('사실', 'NNG'),
#  ('지질', 'NNP'),
#  ('은', 'JX'),
#  ('산패', 'NNP'),
#  ('가', 'JKS'),
#  ('잘', 'MAG'),
#  ('되', 'VV'),
#  ('어서', 'EF'),
#  ('.', 'SF'),
#  ('.', 'SF'),
#  ('얼마나', 'MAG'),
#  ('신선', 'XR'),
#  ('하', 'XSA'),
#  ('게', 'EC'),
#  ('운송', 'NNG'),
#  ('하', 'XSV'),
#  ('아서', 'EC'),
#  ('정밀', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'EC'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('바로', 'MAG'),
#  ('밀봉', 'NNG'),
#  ('하', 'XSV'),
#  ('아서', 'EC'),
#  ('일정', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('온도', 'NNP'),
#  ('와', 'JC'),
#  ('차광', 'NNG'),
#  ('조건', 'NNG'),
#  ('에서', 'JKB'),
#  ('보관', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('게', 'EC'),
#  ('중요', 'XR'),
#  ('하', 'XSA'),
#  ('지', 'EC'),
#  ('...', 'SE'),
#  ('.', 'SF'),
#  ('암', 'NNG'),
#  ('요', 'JX'),
#  (',', 'SP'),
#  ('그럼요', 'IC'),
#  ('.', 'SF'),
#  ('추출', 'NNP'),
#  ('용매', 'NNP'),
#  ('는', 'JX'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('의', 'JKG'),
#  ('PL', 'SL'),
#  ('(', 'SS'),
#  ('Phospholipid', 'SL'),
#  (',', 'SP'),
#  ('인지질', 'NNP'),
#  (')', 'SS'),
#  ('함량', 'NNG'),
#  ('에', 'JKB'),
#  ('중요', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('역할', 'NNG'),
#  ('을', 'JKO'),
#  ('하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('에탄올', 'NNP'),
#  ('(', 'SS'),
#  ('주정', 'NNP'),
#  (')', 'SS'),
#  ('과', 'JC'),
#  ('이', 'MM'),
#  ('소', 'NNP'),
#  ('프로판올', 'NNP'),
#  ('로', 'JKB'),
#  ('ㅜ출한', 'NA'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('은', 'JX'),
#  ('헥산', 'NA'),
#  ('등', 'NNB'),
#  ('다른', 'MM'),
#  ('용매', 'NNP'),
#  ('로', 'JKB'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('때', 'NNG'),
#  ('보다', 'JKB'),
#  ('인지질', 'NNP'),
#  ('함량', 'NNG'),
#  ('이', 'JKS'),
#  ('높', 'VA'),
#  ('아', 'EC'),
#  ('지', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('의', 'JKG'),
#  ('EPA', 'SL'),
#  ('및', 'MAJ'),
#  ('DHA', 'SL'),
#  ('수준', 'NNG'),
#  ('은', 'JX'),
#  ('비슷', 'XR'),
#  ('하', 'XSA'),
#  ('지만', 'EC'),
#  (',', 'SP'),
#  ('어', 'NNG'),
#  ('유의', 'NNP'),
#  ('EPA', 'SL'),
#  ('와', 'JC'),
#  ('DHA', 'SL'),
#  ('는', 'JX'),
#  ('TAG', 'SL'),
#  ('(', 'SS'),
#  ('triglyceride', 'SL'),
#  (')', 'SS'),
#  ('와', 'JC'),
#  ('관련', 'NNG'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('의', 'JKG'),
#  ('EPA', 'SL'),
#  ('및', 'MAJ'),
#  ('DHA', 'SL'),
#  ('는', 'JX'),
#  ('인지질', 'NNP'),
#  ('(', 'SS'),
#  ('PL', 'SL'),
#  (')', 'SS'),
#  ('과', 'JC'),
#  ('관련', 'NNG'),
#  ('이', 'JKS'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('최근', 'NNG'),
#  ('의', 'JKG'),
#  ('연구', 'NNG'),
#  ('에', 'JKB'),
#  ('따르', 'VV'),
#  ('면', 'EC'),
#  ('PLs', 'SL'),
#  ('형태', 'NNG'),
#  ('의', 'JKG'),
#  ('n', 'SL'),
#  ('-3', 'NNP'),
#  ('PUFAs', 'SL'),
#  ('는', 'JX'),
#  ('TAGs', 'SL'),
#  ('형태', 'NNG'),
#  ('보다', 'JKB'),
#  ('생체', 'NNG'),
#  ('이용', 'NNG'),
#  ('률', 'XSN'),
#  ('이', 'JKS'),
#  ('현저히', 'MAG'),
#  ('높', 'VA'),
#  ('다는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('발견', 'NNG'),
#  ('되', 'XSV'),
#  ('었', 'EP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('최근', 'NNG'),
#  ('의', 'JKG'),
#  ('연구', 'NNG'),
#  ('에', 'JKB'),
#  ('따르', 'VV'),
#  ('면', 'EC'),
#  ('PLs', 'SL'),
#  ('형태', 'NNG'),
#  ('의', 'JKG'),
#  ('n', 'SL'),
#  ('-3', 'NNP'),
#  ('PUFAs', 'SL'),
#  ('는', 'JX'),
#  ('TAGs', 'SL'),
#  ('형태', 'NNG'),
#  ('보다', 'JKB'),
#  ('생체', 'NNG'),
#  ('이용', 'NNG'),
#  ('률', 'XSN'),
#  ('이', 'JKS'),
#  ('현저히', 'MAG'),
#  ('높', 'VA'),
#  ('다는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('발견', 'NNG'),
#  ('되', 'XSV'),
#  ('었', 'EP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('출처', 'NNG'),
#  (']', 'SS'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('에', 'JKB'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('2019', 'SN'),
#  ('년', 'NNB'),
#  ('최근', 'NNG'),
#  ('에', 'JKB'),
#  ('게재', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('논문', 'NNP'),
#  ('리뷰', 'NNP'),
#  ('(', 'SS'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('성분', 'NNG'),
#  (',', 'SP'),
#  ('추출', 'NNP'),
#  ('방법', 'NNG'),
#  (',', 'SP'),
#  ('효능', 'NNG'),
#  ('등', 'NNB'),
#  (')', 'SS'),
#  ('|', 'SW'),
#  ('작성자', 'NNG'),
#  ('Emily', 'SL'),
#  ('콜린', 'NNP'),
#  (',', 'SP'),
#  ('치매', 'NNP'),
#  ('.', 'SF'),
#  ('치매', 'NNP'),
#  ('가', 'JKS'),
#  ('걱정', 'NNG'),
#  ('되', 'XSV'),
#  ('면', 'EC'),
#  ('콜린', 'NNP'),
#  ('이', 'VCP'),
#  ('라는', 'ETM'),
#  ('물질', 'NNG'),
#  ('을', 'JKO'),
#  ('잘', 'MAG'),
#  ('외우', 'VV'),
#  ('어', 'EC'),
#  ('두', 'VX'),
#  ('어야', 'EC'),
#  ('하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('남자', 'NNG'),
#  ('에게', 'JKB'),
#  ('좋', 'VA'),
#  ('지만', 'EC'),
#  ('말', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('없', 'VA'),
#  ('는', 'ETM'),
#  ('산수유', 'NNP'),
#  ('던가', 'EF'),
#  ('?', 'SF'),
#  ('그것', 'NP'),
#  ('처럼', 'JKB'),
#  ('콜린', 'NNP'),
#  ('이', 'JKS'),
#  ('들', 'VV'),
#  ('어', 'EC'),
#  ('있', 'VX'),
#  ('어서', 'EC'),
#  ('치매', 'NNP'),
#  ('예방', 'NNG'),
#  ('에', 'JKB'),
#  ('좋', 'VA'),
#  ('다고', 'EC'),
#  ('하', 'VV'),
#  ('면', 'EC'),
#  ('잡혀가', 'VV'),
#  ('는', 'ETM'),
#  ('세상', 'NNG'),
#  ('이', 'VCP'),
#  ('라', 'EC'),
#  ('말', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('순', 'MM'),
#  ('없', 'VA'),
#  ('지만', 'EC'),
#  ('[', 'SS'),
#  ('콜린', 'NNP'),
#  ('치매', 'NNP'),
#  (']', 'SS'),
#  ('이렇', 'VA'),
#  ('게', 'EC'),
#  ('검색', 'NNP'),
#  ('만', 'JX'),
#  ('해보면', 'NNP'),
#  ('요즘', 'NNG'),
#  ('튀어나오', 'VV'),
#  ('는', 'ETM'),
#  ('온갖', 'MM'),
#  ('시', 'NNB'),
#  ('니어', 'NNP'),
#  ('제품', 'NNG'),
#  ('에', 'JKB'),
#  ('뭔', 'MM'),
#  ('놈', 'NNB'),
#  ('의', 'JKG'),
#  ('콜린', 'NNP'),
#  ('이', 'JKS'),
#  ('꼭꼭', 'MAG'),
#  ('들어가', 'VV'),
#  ('아', 'EC'),
#  ('있', 'VV'),
#  ('는지', 'EC'),
#  ('알', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('없', 'VA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('크릴', 'NNP'),
#  ('의', 'JKG'),
#  ('인지질', 'NNP'),
#  ('은', 'JX'),
#  ('뭐', 'NP'),
#  ('다', 'EF'),
#  ('?', 'SF'),
#  ('콜린', 'NNP'),
#  ('이', 'JKS'),
#  ('함유', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('인지질', 'NNP'),
#  ('이', 'VCP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('?', 'SF'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('의', 'JKG'),
#  ('붉', 'VA'),
#  ('은', 'ETM'),
#  ('색', 'NNG'),
#  ('은', 'JX'),
#  ('아', 'NNP'),
#  ('스타', 'NNP'),
#  ('잔틴', 'NNP'),
#  ('때문', 'NNB'),
#  ('이', 'VCP'),
#  ('ㄴ데', 'EC'),
#  (',', 'SP'),
#  ('아', 'NNP'),
#  ('스타', 'NNP'),
#  ('잔틴', 'NNP'),
#  ('은', 'JX'),
#  ('강하', 'VA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('잘', 'MAG'),
#  ('알리', 'VV'),
#  ('어', 'EC'),
#  ('지', 'VX'),
#  ('ㄴ', 'ETM'),
#  ('항산', 'NNP'),
#  ('화제', 'NNP'),
#  ('보다', 'JKB'),
#  ('10', 'SN'),
#  ('배', 'NNP'),
#  ('~', 'SO'),
#  ('100', 'SN'),
#  ('배', 'NNP'),
#  ('는', 'JX'),
#  ('강하', 'VA'),
#  ('ㄴ', 'ETM'),
#  ('항산화물질', 'NNP'),
#  ('아', 'NNP'),
#  ('스타', 'NNP'),
#  ('잔틴', 'NNP'),
#  ('.', 'SF'),
#  ('비타민 E', 'NNP'),
#  ('이것', 'NP'),
#  ('보다', 'JKB'),
#  ('는', 'JX'),
#  ('100', 'SN'),
#  ('배', 'NNP'),
#  ('쎄', 'VA'),
#  ('ㄴ', 'ETM'),
#  ('놈', 'NNB'),
#  ('...', 'SE'),
#  ('좋', 'VA'),
#  ('기', 'ETN'),
#  ('만', 'JX'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('순', 'MM'),
#  ('없', 'VA'),
#  ('지', 'EF'),
#  ('.', 'SF'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('스테롤이', 'NA'),
#  ('들', 'VV'),
#  ('어', 'EC'),
#  ('있', 'VX'),
#  ('는데', 'EC'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('들', 'VV'),
#  ('어', 'EC'),
#  ('있', 'VX'),
#  ('어서', 'EC'),
#  ('식품', 'NNG'),
#  ('보충', 'NNG'),
#  ('제로', 'NNP'),
#  ('먹', 'VV'),
#  ('을', 'ETM'),
#  ('때', 'NNG'),
#  ('좀', 'MAG'),
#  ('걱정', 'NNG'),
#  ('스럽', 'XSA'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('도', 'JX'),
#  ('있', 'VV'),
#  ('음', 'ETN'),
#  ('그러나', 'MAJ'),
#  (',', 'SP'),
#  ('순수', 'NNP'),
#  ('주정', 'NNP'),
#  ('(', 'SS'),
#  ('에탄올', 'NNP'),
#  (')', 'SS'),
#  ('로', 'JKB'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('은', 'JX'),
#  ('물', 'NNG'),
#  ('로', 'JKB'),
#  ('희석', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('에탄올', 'NNP'),
#  ('로', 'JKB'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('보다', 'JKB'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNG'),
#  ('가', 'JKS'),
#  ('낮', 'NNG'),
#  ('을', 'JKO'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('음', 'ETN'),
#  ('.', 'SF'),
#  ('물론', 'MAG'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('의', 'JKG'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNG'),
#  ('를', 'JKO'),
#  ('더', 'MAG'),
#  ('줄이', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('정제', 'NNP'),
#  ('기술', 'NNG'),
#  ('을', 'JKO'),
#  ('탐구', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('필요', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VV'),
#  ('음', 'ETN'),
#  ('지나', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('번', 'NNB'),
#  ('에', 'JKB'),
#  ('주정', 'NNP'),
#  ('으로', 'JKB'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('크릴', 'NNP'),
#  ('오일', 'NNG'),
#  ('이', 'JKS'),
#  ('나쁘', 'VA'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('다고', 'EC'),
#  ('하', 'VV'),
#  ('았', 'EP'),
#  ('는데', 'EC'),
#  ('역시', 'MAJ'),
#  ('..', 'SE'),
#  ('순수', 'NNP'),
#  ('주정', 'NNP'),
#  ('으로', 'JKB'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('면', 'EC'),
#  ('그나마', 'MAG'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('더', 'MAG'),
#  ('적', 'VA'),
#  ('게', 'EC'),
#  ('추출', 'NNG'),
#  ('되', 'XSV'),
#  ('ㅁ', 'ETN'),
#  ('.', 'SF'),
#  ('뭐', 'NP'),
#  ('새우', 'NNP'),
#  ('많이', 'MAG'),
#  ('먹', 'VV'),
#  ('으면', 'EC'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('높', 'VA'),
#  ('아', 'EC'),
#  ('지', 'VX'),
#  ('ㄴ다는', 'ETM'),
#  ('속설', 'NNG'),
#  ('이랑', 'NNP'),
#  ('비슷', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('거', 'NNB'),
#  ('하', 'VX'),
#  ('겠', 'EP'),
#  ('지', 'EC'),
#  ('근데', 'MAJ'),
#  ('그래도', 'MAJ'),
#  ('순수', 'NNP'),
#  ('주정', 'NNP'),
#  ('으로', 'JKB'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('면', 'EC'),
#  ('좀', 'MAG'),
#  ('더', 'MAG'),
#  ('좋', 'VA'),
#  ('다는', 'ETM'),
#  ('얘기', 'NNG'),
#  ('?', 'SF'),
#  ('아', 'NNP'),
#  ('스타', 'NNP'),
#  ('잔틴', 'NNP'),
#  ('으로', 'JKB'),
#  ('도', 'JX'),
#  ('항산', 'NNP'),
#  ('화', 'XSN'),
#  ('효과', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VV'),
#  ('는데', 'EC'),
#  ('크릴', 'NNP'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('토코페롤', 'NNP'),
#  ('도', 'JX'),
#  ('들', 'VV'),
#  ('어', 'EC'),
#  ('있', 'VV'),
#  ('어서', 'EC'),
#  ('다른', 'MM'),
#  ('생리', 'NNG'),
#  ('활성', 'NNG'),
#  ('성분', 'NNG'),
#  ('과', 'JC'),
#  ('시너지', 'NNP'),
#  ('효과', 'NNG'),
#  ('를', 'JKO'),
#  ('내', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('으며', 'EC'),
#  (',', 'SP'),
#  ('냉동', 'NNG'),
#  ('크릴', 'NNP'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('비타민 A', 'NNP'),
#  ('도', 'JX'),
#  ('들', 'VV'),
#  ('어', 'EC'),
#  ('있', 'VX'),
#  ('고', 'EC'),
#  ('추출', 'NNP'),
#  ('중', 'NNB'),
#  ('에', 'JKB'),
#  ...]

# %% [markdown]
# ### 한나눔 파트
# - 딱봐도 구림

# %%
print(han.pos(text))
# Out:
# [('크릴오일', 'N'), ('에', 'J'), ('대하', 'P'), ('ㄴ', 'E'), ('최근', 'N'), ('의', 'J'), ('논문', 'N'), ('을', 'J'), ('좀', 'M'), ('보', 'P'), ('고', 'E'), ('싶', 'P'), ('었다', 'E'), ('.', 'S'), ('퇴근', 'N'), ('길', 'N'), ('에', 'J'), ('스마트폰', 'N'), ('으로', 'J'), ('좀', 'M'), ('찾', 'P'), ('아', 'E'), ('보', 'P'), ('ㄴ', 'E'), ('크릴오', 'N'), ('이', 'J'), ('ㄹ', 'E'), ('논문', 'N'), ('.', 'S'), ('(', 'S'), ('아주', 'M'), ('핸드폰', 'N'), ('용량', 'N'), ('이', 'J'), ('트', 'P'), ('어', 'E'), ('지', 'P'), ('ㄴ다', 'E'), ('..', 'S'), ('요즘', 'N'), (')', 'S'), ('?', 'S'), ('그냥', 'M'), ('scholar', 'F'), ('google', 'F'), ('에서', 'J'), ('krill', 'F'), ('oil', 'F'), ('로', 'J'), ('검색', 'N'), ('하고', 'J'), (',', 'S'), ('기간', 'N'), ('은', 'J'), ('2019년', 'N'), ('으로', 'J'), ('지정', 'N'), ('하', 'X'), ('어서', 'E'), ('제일', 'M'), ('최근', 'N'), ('의', 'J'), ('논문', 'N'), ('을', 'J'), ('검색', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('다음', 'N'), ('뭐', 'N'), ('돌', 'P'), ('ㄴ', 'E'), ('내', 'N'), ('이', 'J'), ('고', 'E'), ('논문', 'N'), ('보', 'P'), ('ㄹ', 'E'), ('그런건', 'N'), ('아니니', 'N'), ('이', 'J'), ('자', 'E'), ('open', 'F'), ('acess', 'F'), ('를', 'J'), ('확인', 'N'), ('마침', 'M'), ('"', 'S'), ('COMPREHENSIVE', 'F'), ('REVIEWS', 'F'), ('IN', 'F'), ('FOOD', 'F'), ('SCIENCE', 'F'), ('AND', 'F'), ('FOOD', 'F'), ('SAFETY', 'F'), ('"', 'S'), ('라고', 'J'), ('SCIE', 'F'), ('급', 'X'), ('의', 'J'), ('저널', 'N'), ('에서', 'J'), ('나', 'P'), ('아', 'E'), ('오', 'P'), ('ㄴ', 'E'), ('리뷰논문', 'N'), ('이', 'J'), ('있', 'P'), ('어서', 'E'), ('읽', 'P'), ('어', 'E'), ('보', 'P'), ('기', 'E'), ('로', 'J'), ('함', 'N'), ('IF', 'F'), ('7점', 'N'), ('정도', 'N'), ('이', 'J'), ('면', 'E'), ('수준', 'N'), ('은', 'J'), ('나쁘', 'P'), ('지', 'E'), ('않', 'P'), ('은', 'E'), ('저널', 'N'), ('크릴오일', 'N'), ('의', 'J'), ('구성성분', 'N'), (',', 'S'), ('추출기법', 'N'), (',', 'S'), ('기능성', 'N'), ('및', 'M'), ('최근', 'M'), ('이슈들', 'N'), ('에', 'J'), ('대하', 'P'), ('ㄴ', 'E'), ('종합적', 'N'), ('검토', 'N'), ('.', 'S'), ('좋', 'P'), ('은', 'E'), ('내용', 'N'), ('이', 'J'), ('겠고', 'E'), (',', 'S'), ('길', 'P'), ('겠구나', 'E'), ('..', 'S'), ('ㅜㅜ', 'N'), ('?', 'S'), ('대충보고', 'N'), ('보', 'P'), ('고', 'E'), ('싶', 'P'), ('은', 'E'), ('부분들', 'N'), ('만', 'J'), ('보', 'N'), ('이', 'J'), ('자면', 'E'), (',', 'S'), ('크릴오일', 'N'), ('은', 'J'), ('2009년', 'N'), ('미국', 'N'), ('에서', 'J'), ('GRAS', 'F'), ('에', 'J'), ('등재', 'N'), ('되', 'X'), ('었고', 'E'), ('유럽에서', 'N'), ('는', 'J'), ('2009년', 'N'), ('Novel', 'F'), ('food', 'F'), ('로', 'J'), ('인정', 'N'), ('받', 'X'), ('아고', 'E'), ('중국에서', 'N'), ('는', 'J'), ('2014년', 'N'), ('에', 'J'), ('식품', 'N'), ('으로', 'J'), ('허용', 'N'), ('되', 'X'), ('었으며', 'E'), (',', 'S'), ('최근', 'N'), ('에는', 'J'), ('유럽에서', 'N'), ('는', 'J'), ('임신', 'N'), ('중', 'N'), ('이', 'J'), ('거나', 'E'), ('수유', 'N'), ('중', 'N'), ('에도', 'J'), ('먹', 'P'), ('을', 'E'), ('수', 'N'), ('있', 'P'), ('다', 'E'), ('고', 'J'), ('결정', 'N'), ('하', 'X'), ('었음', 'E'), ('.', 'S'), ('최근', 'N'), ('에서야', 'J'), ('사람', 'N'), ('이', 'J'), ('먹', 'P'), ('기', 'E'), ('로', 'J'), ('하', 'P'), ('었으나', 'E'), (',', 'S'), ('굉장히', 'M'), ('안전', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('편', 'N'), ('이', 'J'), ('라는', 'E'), ('것', 'N'), ('.', 'S'), ('?', 'S'), ('크릴', 'N'), ('은', 'J'), ('다양한', 'N'), ('지질성분', 'N'), ('프로파일', 'N'), ('을', 'J'), ('보이', 'P'), ('ㄴ데', 'E'), (',', 'S'), ('계절적', 'N'), ('변화', 'N'), (',', 'S'), ('열', 'P'), ('ㄴ', 'E'), ('중', 'N'), ('환경변화', 'N'), (',', 'S'), ('포획', 'N'), ('되', 'X'), ('ㄴ', 'E'), ('크릴', 'N'), ('의', 'J'), ('생육정도', 'N'), (',', 'S'), ('저장', 'N'), ('조건', 'N'), (',', 'S'), ('운송', 'N'), ('조건', 'N'), (',', 'S'), ('원료', 'N'), ('의', 'J'), ('전처리', 'N'), ('방법', 'N'), ('및', 'M'), ('공정', 'N'), ('에', 'J'), ('따르', 'P'), ('아', 'E'), ('지질', 'N'), ('의', 'J'), ('조성', 'N'), ('이', 'J'), ('다르', 'P'), ('아', 'E'), ('지', 'P'), ('ㄴ다', 'E'), ('.', 'S'), ('예', 'N'), ('를', 'J'), ('들', 'P'), ('어', 'E'), (',', 'S'), ('고온', 'N'), ('에서', 'J'), ('탈수(dehydration)할', 'N'), ('경우', 'N'), ('고온', 'N'), ('에서', 'J'), ('지질', 'N'), ('의', 'J'), ('가수분해', 'N'), ('가', 'J'), ('유발', 'N'), ('되', 'X'), ('므로', 'E'), ('동결건조', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('크릴', 'N'), ('에', 'J'), ('비하', 'P'), ('어', 'E'), ('유리지방산 ...
