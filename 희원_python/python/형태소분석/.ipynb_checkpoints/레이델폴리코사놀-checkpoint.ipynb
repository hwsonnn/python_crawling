# %%
from konlpy.tag import *
import time

# %% [markdown]
# ### 오픈소스 형식 형태소 분석기 5가지
# - mecab 확인하고 다시.. 우분투가 잘안되서 패스
# - 한나눔은 너무 성능이 떨어져서 제외. 일단표기는 해둠
# - 카카오 형태소 분석기 카이를 제외한 이유는 사전 추가가 안된다.
#
# - 트위터 분석기, 코모란 두 가지를 중점

# %%
okt = Okt()
han = Hannanum()
komoran = Komoran()
ko = Kkma()

# %%
# 데이터 입수
text = open( '레이델 폴리코사놀.txt' ).read()

# %% [markdown]
# #### 트위터 부분

# %%
# 트위터 morphs
okt_result = okt.morphs(text)
# 트위터 nouns 
okt_result1 = okt.nouns(text)
# 트위터 phrases
okt_result2 = okt.phrases(text)
# 트위터 pos 
okt_result3 = okt.pos(text)

# %%
# 트위터 분석기 
print(okt_result3)
# Out:
# [('레이', 'Noun'), ('델', 'Noun'), ('폴리코사놀', 'Noun'), ('\n', 'Foreign'), ('쿠바', 'Noun'), ('농지', 'Noun'), ('의', 'Josa'), ('약', 'Noun'), ('30%', 'Number'), ('에서', 'Josa'), ('재배', 'Noun'), ('되는', 'Verb'), ('대표', 'Noun'), ('작물', 'Noun'), (',', 'Punctuation'), ('사탕수수', 'Noun'), ('\n', 'Foreign'), ('쿠바', 'Noun'), ('국민', 'Noun'), ('건강', 'Noun'), ('증진', 'Noun'), ('을', 'Josa'), ('위', 'Noun'), ('한', 'Josa'), ('프로젝트', 'Noun'), ('에서', 'Josa'), ('\n', 'Foreign'), ('‘', 'Foreign'), ('들판', 'Noun'), ('에', 'Josa'), ('널린', 'Noun'), ('에너지', 'Noun'), ('저장', 'Noun'), ('고', 'Josa'), ('’', 'Punctuation'), ('라', 'Josa'), ('불리던', 'Verb'), ('\n', 'Foreign'), ('사탕수수', 'Noun'), ('를', 'Josa'), ('떠올린', 'Verb'), ('쿠바', 'Noun'), ('정부', 'Noun'), ('!', 'Punctuation'), ('\n', 'Foreign'), ('사탕수수', 'Noun'), ('100', 'Number'), ('t', 'Alpha'), ('에서', 'Josa'), ('단', 'Noun'), ('2.5', 'Number'), ('kg', 'Alpha'), ('만', 'Noun'), ('추출', 'Noun'), ('할', 'Verb'), ('수', 'Noun'), ('있는', 'Adjective'), ('\n', 'Foreign'), ('사탕수수', 'Noun'), ('왁스', 'Noun'), ('알코올', 'Noun'), ('로', 'Josa'), ('식약처', 'Noun'), ('에서', 'Josa'), ('\n', 'Foreign'), ('콜레스테롤', 'Noun'), ('개선', 'Noun'), ('기능', 'Noun'), ('성', 'Suffix'), ('을', 'Josa'), ('개별', 'Noun'), ('인정받다', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('과학', 'Noun'), ('적', 'Suffix'), ('으로', 'Josa'), ('검증', 'Noun'), ('받은', 'Verb'), ('\n', 'Foreign'), ('폴리코사놀', 'Noun'), ('-', 'Punctuation'), ('사탕수수', 'Noun'), ('왁스', 'Noun'), ('알코올', 'Noun'), ('\n', 'Foreign'), ('레이', 'Noun'), ('델', 'Noun'), ('폴리코사놀', 'Noun'), ('의', 'Josa'), ('주', 'Modifier'), ('원료', 'Noun'), ('인', 'Josa'), ('\n', 'Foreign'), ('폴리코사놀', 'Noun'), ('-', 'Punctuation'), ('사탕수수', 'Noun'), ('왁스', 'Noun'), ('알코올', 'Noun'), ('은', 'Josa'), ('\n', 'Foreign'), ('쿠바', 'Noun'), ('산', 'Noun'), ('사탕수수', 'Noun'), ('잎', 'Noun'), ('과', 'Josa'), ('줄기', 'Noun'), ('에서', 'Josa'), ('추출', 'Noun'), ('정제', 'Noun'), ('한', 'Josa'), ('자연', 'Noun'), ('유래', 'Noun'), ('성분', 'Noun'), ('\n', 'Foreign'), ('“', 'Foreign'), ('혈중', 'Noun'), ('콜레스테롤', 'Noun'), ('수치', 'Noun'), ('개선', 'Noun'), ('에', 'Josa'), ('도움', 'Noun'), ('을', 'Josa'), ('줄', 'Noun'), ('수', 'Noun'), ('있음', 'Adjective'), ('”', 'Foreign'), ('으로', 'Josa'), ('\n', 'Foreign'), ('한국', 'Noun'), ('식약처', 'Noun'), ('로부터', 'Noun'), ('기능', 'Noun'), ('성', 'Suffix'), ('개별', 'Noun'), ('인정', 'Noun'), ('을', 'Josa'), ('받은', 'Verb'), ('\n', 'Foreign'), ('㈜', 'Foreign'), ('레인보우', 'Noun'), ('앤', 'Noun'), ('네이처', 'Noun'), ('코리아', 'Noun'), ('의', 'Josa'), ('독점', 'Noun'), ('원료', 'Noun'), ('\n', 'Foreign'), ('콜레스테롤', 'Noun'), ('수치', 'Noun'), ('개선', 'Noun'), (',', 'Punctuation'), ('\n', 'Foreign'), ('레이', 'Noun'), ('델', 'Noun'), ('폴리코사놀', 'Noun'), ('\n', 'Foreign'), ('좋은', 'Adjective'), ('콜레스테롤', 'Noun'), ('(', 'Punctuation'), ('HDL', 'Alpha'), (')', 'Punctuation'), ('은', 'Noun'), ('높이', 'Noun'), ('고', 'Josa'), (',', 'Punctuation'), ('\n', 'Foreign'), ('나쁜', 'Adjective'), ('콜레스테롤', 'Noun'), ('(', 'Punctuation'), ('LDL', 'Alpha'), (')', 'Punctuation'), ('은', 'Noun'), ('낮추는', 'Verb'), ('\n', 'Foreign'), ('콜레스테롤', 'Noun'), ('수치', 'Noun'), ('개선', 'Noun'), (',', 'Punctuation'), ('\n', 'Foreign'), ('레이', 'Noun'), ('델', 'Noun'), ('폴리코사놀', 'Noun'), ('로', 'Josa'), ('시작', 'Noun'), ('하세요', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('자연', 'Noun'), ('유래', 'Noun'), ('원료', 'Noun'), ('\n', 'Foreign'), ('쿠바', 'Noun'), ('산', 'Noun'), ('사탕수수', 'Noun'), ('에서', 'Josa'), ('\n', 'Foreign'), ('순도', 'Noun'), ('90%', 'Number'), ('이상', 'Noun'), ('추출', 'Noun'), ('·', 'Punctuation'), ('정제', 'Noun'), ('한', 'Josa'), ('원료', 'Noun'), ('\n', 'Foreign'), ('과학', 'Noun'), ('적', 'Suffix'), ('검증', 'Noun'), ('\n', 'Foreign'), ('식약처', 'Noun'), ('기능', 'Noun'), ('성', 'Suffix'), ('원료', 'Noun'), ('인정', 'Noun'), ('\n', 'Foreign'), ('(', 'Punctuation'), ('제', 'Noun'), ('2006-4', 'Number'), ('호', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('철저한', 'Adjective'), ('품질', 'Noun'), ('관리', 'Noun'), ('\n', 'Foreign'), ('공인', 'Noun'), ('시험', 'Noun'), ('기관', 'Noun'), ('을', 'Josa'), ('통해', 'Noun'), ('검사', 'Noun'), ('\ ...

# %% [markdown]
# ### 코모란 부분

# %%
komoran_result = komoran.nouns("\n".join([x for x in text.split("\n") if x]))
komoran_result1 = komoran.morphs("\n".join([x for x in text.split("\n") if x]))
komoran_result2 = komoran.pos("\n".join([x for x in text.split("\n") if x]))

# %%
# 코모란 
komoran_result2
# Out:
# [('레이', 'NNP'),
#  ('데', 'NNB'),
#  ('ㄹ', 'JKO'),
#  ('폴리코사놀', 'NNP'),
#  ('쿠바', 'NNP'),
#  ('농지', 'NNP'),
#  ('의', 'JKG'),
#  ('약', 'MM'),
#  ('30', 'SN'),
#  ('%', 'SW'),
#  ('에서', 'JKB'),
#  ('재배', 'NNG'),
#  ('되', 'XSV'),
#  ('는', 'ETM'),
#  ('대표', 'NNG'),
#  ('작물', 'NNG'),
#  (',', 'SP'),
#  ('사탕수수', 'NNP'),
#  ('쿠바', 'NNP'),
#  ('국민', 'NNG'),
#  ('건강', 'NNG'),
#  ('증진', 'NNG'),
#  ('을', 'JKO'),
#  ('위하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('프로젝트', 'NNP'),
#  ('에서', 'JKB'),
#  ('‘', 'SS'),
#  ('들판', 'NNG'),
#  ('에', 'JKB'),
#  ('널리', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('에너지 저장', 'NNP'),
#  ('이', 'VCP'),
#  ('고', 'EC'),
#  ('’', 'SS'),
#  ('이', 'VCP'),
#  ('라', 'EC'),
#  ('불리', 'VV'),
#  ('던', 'ETM'),
#  ('사탕수수', 'NNP'),
#  ('를', 'JKO'),
#  ('떠올리', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('쿠바', 'NNP'),
#  ('정부', 'NNG'),
#  ('!', 'SF'),
#  ('사탕수수', 'NNP'),
#  ('100', 'SN'),
#  ('t', 'SW'),
#  ('에서', 'JKB'),
#  ('단', 'MM'),
#  ('2', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('kg', 'SW'),
#  ('만', 'JX'),
#  ('추출', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('사탕수수', 'NNP'),
#  ('왁스', 'NNP'),
#  ('알코올', 'NNP'),
#  ('로', 'JKB'),
#  ('식', 'NNG'),
#  ('약', 'NNG'),
#  ('처', 'NNG'),
#  ('에서', 'JKB'),
#  ('콜레스테롤', 'NNP'),
#  ('개선', 'NNG'),
#  ('기능', 'NNG'),
#  ('성', 'XSN'),
#  ('을', 'JKO'),
#  ('개별', 'NNG'),
#  ('인정받', 'VV'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('과학', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('검증', 'NNG'),
#  ('받', 'VV'),
#  ('은', 'ETM'),
#  ('폴리코사놀', 'NNP'),
#  ('-', 'SS'),
#  ('사탕수수', 'NNP'),
#  ('왁스', 'NNP'),
#  ('알코올', 'NNP'),
#  ('레이', 'NNP'),
#  ('데', 'NNB'),
#  ('ㄹ', 'JKO'),
#  ('폴리코사놀', 'NNP'),
#  ('의', 'JKG'),
#  ('주', 'NNG'),
#  ('원료', 'NNG'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETM'),
#  ('폴리코사놀', 'NNP'),
#  ('-', 'SS'),
#  ('사탕수수', 'NNP'),
#  ('왁스', 'NNP'),
#  ('알코올', 'NNP'),
#  ('은', 'JX'),
#  ('쿠바', 'NNP'),
#  ('산', 'NNG'),
#  ('사탕수수', 'NNP'),
#  ('잎', 'NNG'),
#  ('과', 'JC'),
#  ('줄기', 'NNP'),
#  ('에서', 'JKB'),
#  ('추출', 'NNP'),
#  ('정제', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('자연', 'NNG'),
#  ('유래', 'NNG'),
#  ('성분', 'NNG'),
#  ('“', 'SS'),
#  ('혈', 'NNG'),
#  ('중', 'NNB'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('개선', 'NNG'),
#  ('에', 'JKB'),
#  ('도움', 'NNG'),
#  ('을', 'JKO'),
#  ('주', 'VX'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('음', 'ETN'),
#  ('”', 'SS'),
#  ('으로', 'JKB'),
#  ('한국', 'NNP'),
#  ('식', 'NNG'),
#  ('약', 'NNG'),
#  ('처', 'NNG'),
#  ('로부터', 'JKB'),
#  ('기능', 'NNG'),
#  ('성', 'XSN'),
#  ('개별', 'NNG'),
#  ('인정', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('은', 'ETM'),
#  ('㈜', 'SW'),
#  ('레인보우', 'NNP'),
#  ('앤', 'NNP'),
#  ('네이처', 'NNP'),
#  ('코리아', 'NNP'),
#  ('의', 'JKG'),
#  ('독점', 'NNP'),
#  ('원료', 'NNG'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('개선', 'NNG'),
#  (',', 'SP'),
#  ('레이', 'NNP'),
#  ('데', 'NNB'),
#  ('ㄹ', 'JKO'),
#  ('폴리코사놀', 'NNP'),
#  ('좋', 'VA'),
#  ('은', 'ETM'),
#  ('콜레스테롤', 'NNP'),
#  ('(', 'SS'),
#  ('HDL', 'SL'),
#  (')', 'SS'),
#  ('은', 'JX'),
#  ('높이', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('나쁘', 'VA'),
#  ('ㄴ', 'ETM'),
#  ('콜레스테롤', 'NNP'),
#  ('(', 'SS'),
#  ('LDL', 'SL'),
#  (')', 'SS'),
#  ('은', 'JX'),
#  ('낮추', 'VV'),
#  ('는', 'ETM'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('개선', 'NNG'),
#  (',', 'SP'),
#  ('레이', 'NNP'),
#  ('데', 'NNB'),
#  ('ㄹ', 'JKO'),
#  ('폴리코사놀', 'NNP'),
#  ('로', 'JKB'),
#  ('시작', 'NNG'),
#  ('하', 'XSV'),
#  ('시', 'EP'),
#  ('어요', 'EF'),
#  ('.', 'SF'),
#  ('자연', 'NNG'),
#  ('유래', 'NNG'),
#  ('원료', 'NNG'),
#  ('쿠바', 'NNP'),
#  ('산', 'NNG'),
#  ('사탕수수', 'NNP'),
#  ('에서', 'JKB'),
#  ('순도', 'NNP'),
#  ('90', 'SN'),
#  ('%', 'SW'),
#  ('이상', 'NNG'),
#  ('추출', 'NNP'),
#  ('·', 'SP'),
#  ('정제', 'NNP'),
#  ('한', 'NNP'),
#  ('원료', 'NNG'),
#  ('과학', 'NNG'),
#  ('적', 'XSN'),
#  ('검증', 'NNP'),
#  ('식', 'NNG'),
#  ('약', 'NNG'),
#  ('처', 'NNG'),
#  ('기능', 'NNG'),
#  ('성', 'XSN'),
#  ('원료', 'NNG'),
#  ('인정', 'NNG'),
#  ('(', 'SS'),
#  ('제', 'XPN'),
#  ('2006', 'SN'),
#  ('-4', 'NNP'),
#  ('호', 'NNB'),
#  (')', 'SS'),
#  ('철저', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('품질', 'NNP'),
#  ('관리', 'NNP'),
#  ('공인', 'NNP'),
#  ('시험', 'NNP'),
#  ('기관', 'NNG'),
#  ('을', 'JKO'),
#  ('통하', 'VV'),
#  ('아', 'EC'),
#  ('검사', 'NNG'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('개선', 'NNG'),
#  ('레이', 'NNP'),
#  ('데', 'NNB'),
#  ('ㄹ', 'JKO'),
#  ('폴리코사놀', 'NNP'),
#  ('폴리코사놀', 'NNP'),
#  ('5', 'SN'),
#  ('폴리코사놀', 'NNP'),
#  ('-', 'SS'),
#  ('사탕수수', 'NNP'),
#  ('왁스', 'NNP'),
#  ('알코올', 'NNP'),
#  ('은', 'JX'),
#  ('높', 'VA'),
#  ('은', 'ETM'),
#  ('혈', 'NNG'),
#  ('중', 'NNB'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('개선', 'NNG'),
#  ('에', 'JKB'),
#  ('도움', 'NNG'),
#  ('을', 'JKO'),
#  ('주', 'VX'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('레이', 'NNP'),
#  ('데', 'NNB'),
#  ('ㄹ', 'JKO'),
#  ('폴리코사놀', 'NNP'),
#  ('5', 'SN'),
#  ('의', 'JKG'),
#  ('기능', 'NNG'),
#  ('성', 'XSN'),
#  ('원료', 'NNG'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETM'),
#  ('폴리코사놀', 'NNP'),
#  ('-', 'SS'),
#  ('사탕수수', 'NNP'),
#  ('에서', 'JKB'),
#  ('추출', 'NNP'),
#  (',', 'SP'),
#  ('정제', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('자연', 'NNG'),
#  ('유래', 'NNG'),
#  ('성분', 'NNG'),
#  ('으로', 'JKB'),
#  ('충분', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('인체', 'NNP'),
#  ('적용', 'NNG'),
#  ('시험', 'NNG'),
#  ('을', 'JKO'),
#  ('통하', 'VV'),
#  ('아', 'EC'),
#  ('혈액', 'NNP'),
#  ('중', 'NNB'),
#  ('의', 'JKG'),
#  ('총', 'MM'),
#  ('콜레스테롤', 'NNP'),
#  ('과', 'JC'),
#  ('저', 'MM'),
#  ('밀도', 'NNP'),
#  ('지단백', 'NNG'),
#  ('수치', 'NNG'),
#  ('를', 'JKO'),
#  ('감소', 'NNG'),
#  ('시키', 'XSV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('고', 'XPN'),
#  ('밀도', 'NNP'),
#  ('지단백', 'NNG'),
#  ('수치', 'NNG'),
#  ('를', 'JKO'),
#  ('증가', 'NNG'),
#  ('시키', 'XSV'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('을', 'JKO'),
#  ('확인', 'NNG'),
#  ('하', 'XSV'),
#  ('았', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('원료', 'NNG'),
#  ('명', 'NNB'),
#  ('및', 'MAJ'),
#  ('함량', 'NNG'),
#  (':', 'SP'),
#  ('폴리코사놀', 'NNP'),
#  ('-', 'SS'),
#  ('사탕수수', 'NNP'),
#  ('왁스', 'NNP'),
#  ('알코올', 'NNP'),
#  ('(', 'SS'),
#  ('쿠바', 'NNP'),
#  ('산', 'NNG'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('유당혼합분말[유당(미국산),덱스티린],결정셀룰로스,', 'NA'),
#  ('히드', 'NNP'),
#  ('록', 'NNP'),
#  ('시', 'NNG'),
#  ('프로필', 'NNG'),
#  ('메', 'NNG'),
#  ('티', 'NNG'),
#  ('ㄹ', 'JKO'),
#  ('셀', 'NNG'),
#  ('룰', 'NNG'),
#  ('로스', 'NNP'),
#  (',', 'SP'),
#  ('스테아린산마그네슘,', 'NA'),
#  ('치자', 'NNG'),
#  ('청', 'NNP'),
#  ('색소', 'NNP'),
#  (',', 'SP'),
#  ('글리세린지방산에스테르혼합제제(글리세린지방산에스테르,', 'NA'),
#  ('프로', 'NNP'),
#  ('필레', 'NNP'),
#  ('ㄴ', 'ETM'),
#  ('글리', 'NNP'),
#  ('콜', 'NNP'),
#  (',', 'SP'),
#  ('구', 'XPN'),
#  ('연산', 'NNP'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('이산화티타늄(착색료)', 'NA'),
#  (',', 'SP'),
#  ('우유', 'NNP'),
#  ('함유', 'NNG'),
#  ('폴리코사놀', 'NNP'),
#  ('-', 'SS'),
#  ('사탕수수', 'NNP'),
#  ('왁스', 'NNP'),
#  ('알코올', 'NNP'),
#  ('원료', 'NNG'),
#  ('원산지', 'NNG'),
#  (':', 'SP'),
#  ('쿠바', 'NNP'),
#  ('이런', 'MM'),
#  ('분', 'NNB'),
#  ('께', 'JKB'),
#  ('권하', 'VV'),
#  ('아', 'EC'),
#  ('드리', 'VX'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('총', 'MM'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNG'),
#  ('가', 'JKS'),
#  ('높', 'VA'),
#  ('은', 'ETM'),
#  ('분', 'NNB'),
#  ('LDL', 'SL'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNG'),
#  ('가', 'JKS'),
#  ('높', 'VA'),
#  ('은', 'ETM'),
#  ('분', 'NNB'),
#  ('HDL', 'SL'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNG'),
#  ('가', 'JKS'),
#  ('낮', 'VA'),
#  ('은', 'ETM'),
#  ('분', 'NNB'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('개선', 'NNG'),
#  ('을', 'JKO'),
#  ('원하', 'VV'),
#  ('는', 'ETM'),
#  ('중년', 'NNP'),
#  ('남성', 'NNP'),
#  ('분', 'NNB'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNP'),
#  ('개선', 'NNG'),
#  ('을', 'JKO'),
#  ('원하', 'VV'),
#  ('는', 'ETM'),
#  ('페경기', 'NA'),
#  ('이후', 'NNG'),
#  ('여성부', 'NNP'),
#  ('ㄴ', 'JX'),
#  ('섭취', 'NNP'),
#  ('시', 'NNB'),
#  ('주의', 'NNG'),
#  ('사항', 'NNG'),
#  ('일일', 'NNG'),
#  ('섭취량', 'NNG'),
#  ('보다', 'JKB'),
#  ('과다', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'EC'),
#  ('섭취', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('도록', 'EC'),
#  ('주의', 'NNG'),
#  ('하', 'XSV'),
#  ('시', 'EP'),
#  ('기', 'ETN'),
#  ('바라', 'VV'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('콜레스테롤', 'NNP'),
#  ('합성', 'NNG'),
#  ('에', 'JKB'),
#  ('영향', 'NNG'),
#  ('을', 'JKO'),
#  ('주', 'VX'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('으므로', 'EC'),
#  ('임산부', 'NNG'),
#  (',', 'SP'),
#  ('수', 'NNB'),
#  ('유부', 'NNP'),
#  (',', 'SP'),
#  ('영유아', 'NNG'),
#  (',', 'SP'),
#  ('어린이', 'NNG'),
#  (',', 'SP'),
#  ('청소년', 'NNG'),
#  ('은', 'JX'),
#  ('섭취', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('좋', 'VA'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('콜레스테롤', 'NNP'),
#  ('저하', 'NNG'),
#  ('를', 'JKO'),
#  ('위하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('의약품', 'NNP'),
#  ('과', 'JC'),
#  ('함께', 'MAG'),
#  ('섭취', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('도록', 'EC'),
#  ('하', 'VV'),
#  ('아야', 'EC'),
#  ('하', 'VX'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('혈액', 'NNP'),
#  ('응고', 'NNP'),
#  ('를', 'JKO'),
#  ('저해', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('으므로', 'EC'),
#  ('주의', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('사용', 'NNG'),
#  ('하', 'XSV'),
#  ('시', 'EP'),
#  ('기', 'ETN'),
#  ('바라', 'VV'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('콜레스테롤', 'NNP'),
#  ('간', 'NNB'),
#  ('리', 'NNP'),
#  ('를', 'JKO'),
#  ('하', 'VV'),
#  ('아야', 'EC'),
#  ('하', 'VX'),
#  ('는', 'ETM'),
#  ('이유', 'NNG'),
#  ('식품', 'NNG'),
#  ('으로', 'JKB'),
#  ('섭취', 'NNG'),
#  ('하', 'XSV'),
#  ('거나', 'EC'),
#  ('몸', 'NNG'),
#  ('에서', 'JKB'),
#  ('만들', 'VV'),
#  ('어', 'EC'),
#  ('지', 'VX'),
#  ('ㄴ', 'ETM'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('우리', 'NP'),
#  ('몸', 'NNG'),
#  ('구석구석', 'NNG'),
#  ('에', 'JKB'),
#  ('쓰이', 'VV'),
#  ('려면', 'EC'),
#  ('혈액', 'NNG'),
#  ('을', 'JKO'),
#  ('타', 'VV'),
#  ('고', 'EC'),
#  ('이동', 'NNG'),
#  ('하', 'XSV'),
#  ('아야', 'EC'),
#  ('하', 'VX'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('이', 'MM'),
#  ('때', 'NNG'),
#  ('지방', 'NNG'),
#  ('성분', 'NNG'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETM'),
#  ('콜레스테롤', 'NNP'),
#  ('은', 'JX'),
#  ('혈액', 'NNG'),
#  ('에', 'JKB'),
#  ('녹지', 'NNG'),
#  ('않', 'VX'),
#  ('아', 'EC'),
#  ('덩어리', 'NNG'),
#  ('를', 'JKO'),
#  ('형성', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('이동', 'NNG'),
#  ('하', 'XSV'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('지단백', 'NNG'),
#  ('중', 'NNB'),
#  ('에', 'JKB'),
#  ('LDL', 'SL'),
#  ('은', 'JX'),
#  ('콜레스테롤', 'NNP'),
#  ('을', 'JKO'),
#  ('세포', 'NNP'),
#  ('로', 'JKB'),
#  ('운반', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('이용', 'NNG'),
#  ('하', 'XSV'),
#  ('도록', 'EC'),
#  ('하', 'VV'),
#  ('는', 'ETM'),
#  ('역할', 'NNG'),
#  ('을', 'JKO'),
#  ('하', 'VX'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('그러나', 'MAJ'),
#  ('LDL', 'SL'),
#  ('은', 'JX'),
#  ('산화', 'NNG'),
#  ('되', 'XSV'),
#  ('기', 'ETN'),
#  ('쉽', 'VA'),
#  ('어서', 'EC'),
#  ('혈액', 'NNP'),
#  ('조직', 'NNP'),
#  ('에', 'JKB'),
#  ('손상', 'NNG'),
#  ('을', 'JKO'),
#  ('주', 'VX'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('는데', 'EC'),
#  (',', 'SP'),
#  ('손상', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('혈관', 'NNP'),
#  ('조직', 'NNP'),
#  ('에', 'JKB'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('쌓이', 'VV'),
#  ('어', 'EC'),
#  ('플라크', 'NNP'),
#  ('를', 'JKO'),
#  ('형성', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'EC'),
#  ('도비', 'NNP'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('플르카ㅡ', 'NA'),
#  ('형성', 'NNG'),
#  ('은', 'JX'),
#  ('혈관', 'NNG'),
#  ('을', 'JKO'),
#  ('좁', 'VA'),
#  ('게', 'EC'),
#  ('만들', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('혈관', 'NNP'),
#  ('의', 'JKG'),
#  ('기능', 'NNG'),
#  ('도', 'JX'),
#  ('떨어지', 'VV'),
#  ('게', 'EC'),
#  ('하', 'VX'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('고기', 'NNG'),
#  ('를', 'JKO'),
#  ('잘', 'MAG'),
#  ('먹', 'VV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('는데', 'EC'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('높', 'VA'),
#  ('은', 'ETM'),
#  ('이유', 'NNG'),
#  ('는', 'JX'),
#  ('?', 'SF'),
#  ('우리', 'NP'),
#  ('몸', 'NNG'),
#  ('의', 'JKG'),
#  ('콜레스테롤', 'NNP'),
#  ('은', 'JX'),
#  ('음식', 'NNG'),
#  ('섭취', 'NNG'),
#  ('를', 'JKO'),
#  ('통하', 'VV'),
#  ('아서', 'EC'),
#  ('얻', 'VV'),
#  ('어', 'EC'),
#  ('지', 'VX'),
#  ('기', 'ETN'),
#  ('도', 'JX'),
#  ('하지만', 'MAJ'),
#  ('간', 'NNB'),
#  ('에서', 'JKB'),
#  ('도', 'JX'),
#  ('콜레스테롤', 'NNP'),
#  ('을', 'JKO'),
#  ('생성', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('내', 'VX'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('이', 'NP'),
#  ('처럼', 'JKB'),
#  ('몸', 'NNG'),
#  ('안', 'NNG'),
#  ('에서', 'JKB'),
#  ('바로', 'MAG'),
#  ('만들', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('전체', 'NNG'),
#  ('콜레스테롤', 'NNP'),
#  ('의', 'JKG'),
#  ('80', 'SN'),
#  ('%', 'SW'),
#  ('정도', 'NNG'),
#  ('로', 'JKB'),
#  ('많', 'VA'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('음식', 'NNG'),
#  ('을', 'JKO'),
#  ('통하', 'VV'),
#  ('아서', 'EC'),
#  ('얻', 'VV'),
#  ('어', 'EC'),
#  ('지', 'VX'),
#  ('는', 'ETM'),
#  ('비율', 'NNG'),
#  ('은', 'JX'),
#  ('20', 'SN'),
#  ('%', 'SW'),
#  ('정도', 'NNG'),
#  ('로', 'JKB'),
#  ('비교', 'NNG'),
#  ('적', 'XSN'),
#  ('적', 'VA'),
#  ('은', 'ETM'),
#  ('편', 'NNB'),
#  ('이', 'VCP'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('즉', 'MAJ'),
#  (',', 'SP'),
#  ('음식', 'NNG'),
#  ('을', 'JKO'),
#  ('통하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('콜레스테롤', 'NNP'),
#  ('의', 'JKG'),
#  ('흡수', 'NNG'),
#  ('보다', 'JKB'),
#  ('는', 'JX'),
#  ('간', 'NNB'),
#  ('에서', 'JKB'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('많이', 'MAG'),
#  ('만들', 'VV'),
#  ('어', 'EC'),
#  ('지', 'VX'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('더', 'MAG'),
#  ('문제', 'NNG'),
#  ('가', 'JKS'),
#  ('되', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('따라서', 'MAJ'),
#  ('고기', 'NNG'),
#  ('를', 'JKO'),
#  ('잘', 'MAG'),
#  ('먹', 'VV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('는다', 'EC'),
#  ('하', 'VV'),
#  ('더라도', 'EC'),
#  ('콜레스테롤', 'NNP'),
#  ('이', 'JKS'),
#  ('몸', 'NNG'),
#  ('안', 'NNG'),
#  ('에서', 'JKB'),
#  ('많이', 'MAG'),
#  ('만들', 'VV'),
#  ('어', 'EC'),
#  ('지', 'VX'),
#  ('는', 'ETM'),
#  ('경우', 'NNG'),
#  ('이', 'VCP'),
#  ('라면', 'EC'),
#  ('콜레스테롤', 'NNP'),
#  ('수치', 'NNG'),
#  ('가', 'JKS'),
#  ('높', 'VA'),
#  ('을', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('<', 'SS'),
#  ('<', 'SS'),
#  ('https', 'SL'),
#  (':', 'SP'),
#  ('/', 'SP'),
#  ('/', 'SP'),
#  ('www', 'SL'),
#  ('.', 'SF'),
#  ('raydel', 'SL'),
#  ('.co', 'NNP'),
#  ('.kr', 'NNP'),
#  ('/', 'SP'),
#  ('goods', 'SL'),
#  ('/', 'SP'),
#  ('goods', 'SL'),
#  ('_', 'SW'),
#  ('list', 'SL'),
#  ('.', 'SF'),
#  ('php', 'SL'),
#  ('?', 'SF'),
#  ('cateCd', 'SL'),
#  ('=', 'SW'),
#  ('060', 'SN'),
#  ('>', 'SS'),
#  ('>', 'SS')]

# %% [markdown]
# ### 한나눔 파트
# - 딱봐도 구림

# %%
print(han.pos(text))
# Out:
# [('레이델', 'N'), ('폴리코사놀', 'N'), ('쿠바', 'N'), ('농지', 'N'), ('의', 'J'), ('약', 'N'), ('30', 'N'), ('%', 'S'), ('에서', 'J'), ('재배', 'N'), ('되', 'X'), ('는', 'E'), ('대표', 'N'), ('작물', 'N'), (',', 'S'), ('사탕수수', 'N'), ('쿠바', 'N'), ('국민', 'N'), ('건강', 'N'), ('증진', 'N'), ('을', 'J'), ('위하', 'P'), ('ㄴ', 'E'), ('프로젝트', 'N'), ('에서', 'J'), ('‘들판', 'N'), ('에', 'J'), ('널리', 'P'), ('ㄴ', 'E'), ('에너지', 'N'), ('저장고’라', 'N'), ('불리', 'N'), ('이', 'J'), ('던', 'E'), ('사탕수수', 'N'), ('를', 'J'), ('떠올리', 'P'), ('ㄴ', 'E'), ('쿠바', 'N'), ('정부', 'N'), ('!', 'S'), ('사탕수수', 'N'), ('100t', 'N'), ('에서', 'J'), ('달', 'P'), ('ㄴ', 'E'), ('2.', 'N'), ('5kg만', 'N'), ('추출', 'N'), ('하', 'X'), ('ㄹ', 'E'), ('수', 'N'), ('있', 'P'), ('는', 'E'), ('사탕수수왁스알코올', 'N'), ('로', 'J'), ('식약처', 'N'), ('에서', 'J'), ('콜레스테롤', 'N'), ('개', 'N'), ('선', 'J'), ('기능성', 'N'), ('을', 'J'), ('개별', 'N'), ('인정', 'N'), ('받', 'X'), ('다', 'E'), ('.', 'S'), ('과학적', 'N'), ('으로', 'J'), ('검증', 'N'), ('받', 'X'), ('은', 'E'), ('폴리코사놀', 'N'), ('-', 'S'), ('사탕수수왁스알코올', 'N'), ('레이델', 'N'), ('폴리코사놀', 'N'), ('의', 'J'), ('주원료인', 'N'), ('폴리코사놀', 'N'), ('-', 'S'), ('사탕수수왁스알코올', 'N'), ('은', 'J'), ('쿠바산', 'N'), ('사탕수수', 'N'), ('잎', 'N'), ('과', 'J'), ('줄', 'P'), ('기', 'E'), ('에서', 'J'), ('추출', 'N'), ('정제', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('자연유래성분', 'N'), ('“혈중', 'N'), ('콜레스테롤', 'N'), ('수치', 'N'), ('개선', 'N'), ('에', 'J'), ('도움', 'N'), ('을', 'J'), ('주', 'P'), ('ㄹ', 'E'), ('수', 'N'), ('있음”', 'N'), ('으로', 'J'), ('한국', 'N'), ('식약처로부터', 'N'), ('기능성', 'N'), ('개별인정', 'N'), ('을', 'J'), ('받', 'P'), ('은', 'E'), ('㈜레인보우앤네이처코리아', 'N'), ('의', 'J'), ('독점', 'N'), ('원료', 'N'), ('콜레스테롤', 'N'), ('수치', 'N'), ('개선', 'N'), (',', 'S'), ('레이델', 'N'), ('폴리코사놀', 'N'), ('좋', 'P'), ('은', 'E'), ('콜레스테롤(HDL)', 'N'), ('은', 'J'), ('높이', 'N'), ('고', 'J'), (',', 'S'), ('나쁘', 'P'), ('ㄴ', 'E'), ('콜레스테롤(LDL)', 'N'), ('은', 'J'), ('낮추', 'M'), ('는', 'J'), ('콜레스테롤', 'N'), ('수치', 'N'), ('개선', 'N'), (',', 'S'), ('레이델', 'N'), ('폴리코사놀', 'N'), ('로', 'J'), ('시작', 'N'), ('하', 'X'), ('세', 'E'), ('요', 'J'), ('.', 'S'), ('자연', 'N'), ('유래', 'N'), ('원료', 'N'), ('쿠바산', 'N'), ('사탕수수', 'N'), ('에서', 'J'), ('순', 'N'), ('도', 'J'), ('90', 'N'), ('%', 'S'), ('이상', 'N'), ('추출·정제한', 'N'), ('원료', 'N'), ('과학적', 'N'), ('검증', 'N'), ('식약처', 'N'), ('기능성', 'N'), ('원료', 'N'), ('인정', 'N'), ('(', 'S'), ('제', 'N'), ('2006-4호', 'N'), (')', 'S'), ('철저', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('품질관리', 'N'), ('공인시험기관', 'N'), ('을', 'J'), ('통하', 'P'), ('어', 'E'), ('검사', 'N'), ('콜레스테롤', 'N'), ('수치', 'N'), ('개선', 'N'), ('레이델', 'N'), ('폴리코사놀', 'N'), ('폴리코사놀5', 'N'), ('폴리코사놀-사탕수수왁스알코올', 'N'), ('은', 'J'), ('높', 'P'), ('은', 'E'), ('혈중', 'N'), ('콜레스테롤', 'N'), ('수치', 'N'), ('개선', 'N'), ('에', 'J'), ('도움', 'N'), ('을', 'J'), ('주', 'P'), ('ㅂ니다', 'E'), ('.', 'S'), ('레이델', 'N'), ('폴리코사놀5', 'N'), ('의', 'J'), ('기능성', 'N'), ('원료', 'N'), ('이', 'J'), ('ㄴ', 'E'), ('폴리코사놀-사탕수수', 'N'), ('에서', 'J'), ('추출', 'N'), (',', 'S'), ('정제', 'N'), ('하', 'X'), ('ㄴ', 'E'), ('자연유래성분', 'N'), ('으로', 'J'), ('충분한', 'N'), ('인체적용시험', 'N'), ('을', 'J'), ('통하', 'P'), ('어', 'E'), ('혈액', 'N'), ('중', 'N'), ('의', 'J'), ('총', 'M'), ('콜레스테롤', 'N'), ('과', 'J'), ('저밀도지단백', 'N'), ('수치', 'N'), ('를', 'J'), ('감소', 'N'), ('시키', 'X'), ('고', 'E'), (',', 'S'), ('고밀도', 'N'), ('지단백', 'N'), ('수치', 'N'), ('를', 'J'), ('증가', 'N'), ('시키', 'X'), ('는', 'E'), ('것', 'N'), ('을', 'J'), ('확인', 'N'), ('하', 'X'), ('었습니다', 'E'), ('.', 'S'), ('원료명', 'N'), ('및', 'M'), ('함량', 'N'), (':', 'S'), ('폴리코사놀', 'N'), ('-', 'S'), ('사탕수수왁스알코올(쿠바산),', 'N'), ('유당혼합분말[유당(미국산),덱스티린],결정셀룰로스,', 'N'), ('히드록시프로필메틸셀룰로스,', 'N'), ('스테아린산마그네슘', 'N'), (',', 'S'), ('치자청색소', 'N'), (',', 'S'), ('글리세린지방산에스테르혼합제제(글리세린지방산에스테르,', 'N'), ('프로필렌글리콜,', 'N'), ('구연산),', 'N'), ('이산화티타늄(착색료)', 'N'), (',', 'S'), ('우유', 'N'), ('함유', 'N'), ('폴리코사놀-사탕수수왁스', 'N'), ('알코올', 'N'), ('원료', 'N'), ('원산지', 'N'), (':', 'S'), ('쿠바', 'N'), ('이런', 'M'), ('분', 'N'), ('께', 'J'), ('권하', 'P'), ('어', 'E'), ('드리', 'P'), ('ㅂ니다', 'E'), ('.', 'S'), ('총', 'M'), ('콜레스테롤', 'N'), ('수치', 'N'), ('가', 'J'), ('높', 'P'), ('은', 'E'), ('분', 'N'), ('LDL', 'F'), ('콜레스테 ...
