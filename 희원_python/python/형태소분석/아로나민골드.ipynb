# %%
from konlpy.tag import *
import time

# %% [markdown]
# ### 오픈소스 형식 형태소 분석기 5가지
# - mecab 확인하고 다시.. 우분투가 잘안되서 패스
# - 한나눔은 너무 성능이 떨어져서 제외. 일단표기는 해둠
# - 카카오 형태소 분석기 카이를 제외한 이유는 사전 추가가 안된다.
#
# - 트위터 분석기, 코모란 두 가지를 중점

# %%
okt = Okt()
han = Hannanum()
komoran = Komoran()
ko = Kkma()

# %%
# 데이터 입수
text = open( '아로나민골드.txt' ).read()

# %% [markdown]
# #### 트위터 부분

# %%
# 트위터 morphs
okt_result = okt.morphs(text)
# 트위터 nouns 
okt_result1 = okt.nouns(text)
# 트위터 phrases
okt_result2 = okt.phrases(text)
# 트위터 pos 
okt_result3 = okt.pos(text)

# %%
# 트위터 분석기 
print(okt_result3)
# Out:
# [('성분', 'Noun'), ('/', 'Punctuation'), ('함량', 'Noun'), ('\n', 'Foreign'), ('원료', 'Noun'), ('약품', 'Noun'), ('및', 'Noun'), ('분량', 'Noun'), ('(', 'Punctuation'), ('1', 'Number'), ('정', 'Noun'), ('중', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('유효', 'Noun'), ('성분', 'Noun'), (':', 'Punctuation'), ('\n ', 'Foreign'), ('푸르', 'Adjective'), ('설', 'Noun'), ('티아민', 'Noun'), ('(', 'Punctuation'), ('활', 'Noun'), ('성', 'Modifier'), ('비타민', 'Noun'), ('B', 'Alpha'), ('1', 'Number'), (')', 'Punctuation'), ('(', 'Punctuation'), ('KP', 'Alpha'), (')', 'Punctuation'), ('50.0', 'Number'), ('mg', 'Alpha'), ('\n ', 'Foreign'), ('리보플라빈', 'Noun'), ('부', 'Noun'), ('티레', 'Noun'), ('이', 'Suffix'), ('트', 'Noun'), ('(', 'Punctuation'), ('활', 'Noun'), ('성', 'Modifier'), ('비타민', 'Noun'), ('B', 'Alpha'), ('2', 'Number'), (')', 'Punctuation'), ('(', 'Punctuation'), ('KP', 'Alpha'), (')', 'Punctuation'), ('2.5', 'Number'), ('mg', 'Alpha'), ('\n ', 'Foreign'), ('피리독살', 'Noun'), ('포스', 'Noun'), ('페이트', 'Noun'), ('수화물', 'Noun'), ('(', 'Punctuation'), ('활', 'Noun'), ('성', 'Modifier'), ('비타민', 'Noun'), ('B', 'Alpha'), ('6', 'Number'), (')', 'Punctuation'), ('(', 'Punctuation'), ('KP', 'Alpha'), (')', 'Punctuation'), ('2.5', 'Number'), ('mg', 'Alpha'), ('\n ', 'Foreign'), ('히', 'Adverb'), ('드록', 'Noun'), ('소', 'Modifier'), ('코발라민', 'Noun'), ('아세트산염', 'Noun'), ('(', 'Punctuation'), ('활', 'Noun'), ('성', 'Modifier'), ('비타민', 'Noun'), ('B', 'Alpha'), ('12', 'Number'), (')', 'Punctuation'), ('(', 'Punctuation'), ('KP', 'Alpha'), (')', 'Punctuation'), ('5.22', 'Number'), ('㎍', 'Foreign'), ('\n ', 'Foreign'), ('아스코르브산', 'Noun'), ('(', 'Punctuation'), ('비타민', 'Noun'), ('C', 'Alpha'), (')', 'Punctuation'), ('(', 'Punctuation'), ('직', 'Noun'), ('타용', 'Noun'), (')(', 'Punctuation'), ('별', 'Modifier'), ('규', 'Noun'), (')(', 'Punctuation'), ('아스코르브산', 'Noun'), ('으로서', 'Josa'), ('70.0', 'Number'), ('mg', 'Alpha'), (')', 'Punctuation'), ('72.2', 'Number'), ('mg', 'Alpha'), ('\n ', 'Foreign'), ('토코페롤', 'Noun'), ('아세테이트', 'Noun'), ('2', 'Number'), ('배산', 'Noun'), ('(', 'Punctuation'), ('비타민', 'Noun'), ('E', 'Alpha'), ('로서', 'Noun'), ('20', 'Number'), ('IU', 'Alpha'), (')', 'Punctuation'), ('(', 'Punctuation'), ('KP', 'Alpha'), (')(', 'Punctuation'), ('토코페롤', 'Noun'), ('아세테이트', 'Noun'), ('로서', 'Noun'), ('20.0', 'Number'), ('mg', 'Alpha'), (')', 'Punctuation'), ('40.0', 'Number'), ('mg', 'Alpha'), ('\n', 'Foreign'), ('첨가제', 'Noun'), ('(', 'Punctuation'), ('타르', 'Noun'), ('색소', 'Noun'), (')', 'Punctuation'), (':', 'Punctuation'), ('\n ', 'Foreign'), ('적색', 'Noun'), ('40', 'Number'), ('호', 'Noun'), (',', 'Punctuation'), ('청색', 'Noun'), ('2', 'Number'), ('호', 'Noun'), (',', 'Punctuation'), ('황색', 'Noun'), ('203', 'Number'), ('호', 'Noun'), ('\n', 'Foreign'), ('첨가제', 'Noun'), ('(', 'Punctuation'), ('동물', 'Noun'), ('유래', 'Noun'), ('성분', 'Noun'), (')', 'Punctuation'), (':', 'Punctuation'), ('\n ', 'Foreign'), ('유당', 'Noun'), ('수화물', 'Noun'), ('(', 'Punctuation'), ('소', 'Noun'), (',', 'Punctuation'), ('우유', 'Noun'), (')', 'Punctuation'), ('\n', 'Foreign'), ('기타', 'Noun'), ('첨가제', 'Noun'), (':', 'Punctuation'), ('\n ', 'Foreign'), ('미결', 'Noun'), ('정', 'Noun'), ('셀룰로오스', 'Noun'), (',', 'Punctuation'), ('스테아르산', 'Noun'), ('마그네슘', 'Noun'), (',', 'Punctuation'), ('오파', 'Noun'), ('드라이', 'Noun'), ('빨간색', 'Noun'), ('(', 'Punctuation'), ('OY', 'Alpha'), ('-', 'Punctuation'), ('25014', 'Number'), ('),', 'Punctuation'), ('오파', 'Noun'), ('드라이', 'Noun'), ('클리어', 'Noun'), ('(', 'Punctuation'), ('OY', 'Alpha'), ('-', 'Punctuation'), ('S', 'Alpha'), ('-', 'Punctuation'), ('29019', 'Number'), ('),', 'Punctuation'), ('\n ', 'Foreign'), ('코', 'Noun'), ('포비', 'Noun'), ('돈', 'Noun'), (',', 'Punctuation'), ('콜로이드', 'Noun'), ('성', 'Modifier'), ('이산화규소', 'Noun'), (',', 'Punctuation'), ('크로스', 'Noun'), ('포비', 'Noun'), ('돈', 'Noun'), ('\n', 'Foreign'), ('효능', 'Noun'), ('/', 'Punctuation'), ('효과', 'Noun'), ('\n', 'Foreign'), ('다음', 'Noun'), ('경우', 'Noun'), ('의', 'Josa'), ('비타민', 'Noun'), ('B', 'Alpha'), ('1', ' ...

# %% [markdown]
# ### 코모란 부분

# %%
komoran_result = komoran.nouns("\n".join([x for x in text.split("\n") if x]))
komoran_result1 = komoran.morphs("\n".join([x for x in text.split("\n") if x]))
komoran_result2 = komoran.pos("\n".join([x for x in text.split("\n") if x]))

# %%
# 코모란 
komoran_result2
# Out:
# [('성분', 'NNG'),
#  ('/', 'SP'),
#  ('함량', 'NNG'),
#  ('원료', 'NNG'),
#  ('약품', 'NNG'),
#  ('및', 'MAJ'),
#  ('분량', 'NNG'),
#  ('(', 'SS'),
#  ('1', 'SN'),
#  ('정', 'NNP'),
#  ('중', 'NNB'),
#  (')', 'SS'),
#  ('유효', 'NNG'),
#  ('성분', 'NNG'),
#  (':', 'SP'),
#  ('푸르', 'VA'),
#  ('서', 'EF'),
#  ('ㄹ', 'ETM'),
#  ('티아민', 'NNP'),
#  ('(', 'SS'),
#  ('활성', 'NNG'),
#  ('비타민', 'NNP'),
#  ('B1', 'NNP'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('KP', 'SL'),
#  (')', 'SS'),
#  ('50', 'SN'),
#  ('.', 'SF'),
#  ('0', 'SN'),
#  ('mg', 'SL'),
#  ('리보플라빈', 'NNG'),
#  ('부', 'XPN'),
#  ('티레', 'NNP'),
#  ('이', 'NNP'),
#  ('트', 'VV'),
#  ('(', 'SS'),
#  ('활성', 'NNG'),
#  ('비타민', 'NNP'),
#  ('B2', 'NNP'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('KP', 'SL'),
#  (')', 'SS'),
#  ('2', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('mg', 'SL'),
#  ('피리', 'NNP'),
#  ('독살', 'NNP'),
#  ('포스', 'NNP'),
#  ('페이', 'NNP'),
#  ('트', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수화물', 'NNP'),
#  ('(', 'SS'),
#  ('활성', 'NNG'),
#  ('비타민', 'NNP'),
#  ('B6', 'NNP'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('KP', 'SL'),
#  (')', 'SS'),
#  ('2', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('mg', 'SL'),
#  ('히드', 'NNP'),
#  ('록', 'NNP'),
#  ('소코', 'NNP'),
#  ('발라', 'NNP'),
#  ('민', 'NNP'),
#  ('아세트산', 'NNP'),
#  ('염', 'NNP'),
#  ('(', 'SS'),
#  ('활성', 'NNG'),
#  ('비타민', 'NNP'),
#  ('B', 'SL'),
#  ('12', 'SN'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('KP', 'SL'),
#  (')', 'SS'),
#  ('5', 'SN'),
#  ('.', 'SF'),
#  ('22', 'SN'),
#  ('㎍', 'SH'),
#  ('아스코르브산', 'NNP'),
#  ('(', 'SS'),
#  ('비타민', 'NNP'),
#  ('C', 'SL'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('직', 'NNG'),
#  ('타', 'NNG'),
#  ('용', 'XSN'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('별', 'NNG'),
#  ('규', 'NNG'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('아스코르브산', 'NNP'),
#  ('으로서', 'JKB'),
#  ('70', 'SN'),
#  ('.', 'SF'),
#  ('0', 'SN'),
#  ('mg', 'SL'),
#  (')', 'SS'),
#  ('72', 'SN'),
#  ('.', 'SF'),
#  ('2', 'SN'),
#  ('mg', 'SL'),
#  ('토코페롤', 'NNP'),
#  ('아세테이트', 'NNP'),
#  ('2', 'SN'),
#  ('배사', 'NNP'),
#  ('ㄴ', 'JX'),
#  ('(', 'SS'),
#  ('비타민', 'NNP'),
#  ('E', 'SL'),
#  ('로서', 'JKB'),
#  ('20', 'SN'),
#  ('IU', 'SL'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('KP', 'SL'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('토코페롤', 'NNP'),
#  ('아세테이트', 'NNP'),
#  ('로서', 'JKB'),
#  ('20', 'SN'),
#  ('.', 'SF'),
#  ('0', 'SN'),
#  ('mg', 'SL'),
#  (')', 'SS'),
#  ('40', 'SN'),
#  ('.', 'SF'),
#  ('0', 'SN'),
#  ('mg', 'SL'),
#  ('첨가제', 'NNG'),
#  ('(', 'SS'),
#  ('타르', 'NNP'),
#  ('색소', 'NNP'),
#  (')', 'SS'),
#  (':', 'SP'),
#  ('적색', 'NNG'),
#  ('40', 'SN'),
#  ('호', 'NNB'),
#  (',', 'SP'),
#  ('청색', 'NNG'),
#  ('2', 'SN'),
#  ('호', 'NNB'),
#  (',', 'SP'),
#  ('황색', 'NNG'),
#  ('203', 'SN'),
#  ('호', 'NNB'),
#  ('첨가제', 'NNG'),
#  ('(', 'SS'),
#  ('동물', 'NNP'),
#  ('유래', 'NNG'),
#  ('성분', 'NNG'),
#  (')', 'SS'),
#  (':', 'SP'),
#  ('유당', 'NNP'),
#  ('수화물', 'NNP'),
#  ('(', 'SS'),
#  ('소', 'NNP'),
#  (',', 'SP'),
#  ('우유', 'NNP'),
#  (')', 'SS'),
#  ('기타', 'NNG'),
#  ('첨가제', 'NNG'),
#  (':', 'SP'),
#  ('미', 'NNP'),
#  ('결정', 'NNP'),
#  ('셀', 'NNG'),
#  ('룰', 'NNG'),
#  ('로', 'NNG'),
#  ('오스', 'NNP'),
#  (',', 'SP'),
#  ('스테아르산', 'NNP'),
#  ('마그네슘', 'NNP'),
#  (',', 'SP'),
#  ('오', 'NNP'),
#  ('파', 'NNG'),
#  ('드라이', 'NNG'),
#  ('빨간색', 'NNG'),
#  ('(', 'SS'),
#  ('OY', 'SL'),
#  ('-', 'SS'),
#  ('25014', 'SN'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('오', 'NNP'),
#  ('파', 'NNG'),
#  ('드라이', 'NNG'),
#  ('크', 'VA'),
#  ('ㄹ', 'ETM'),
#  ('리어', 'NNP'),
#  ('(', 'SS'),
#  ('OY', 'SL'),
#  ('-', 'SS'),
#  ('S', 'SL'),
#  ('-', 'SS'),
#  ('29019', 'SN'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('코', 'NNG'),
#  ('포', 'NNP'),
#  ('비도', 'NNP'),
#  ('ㄴ', 'JX'),
#  (',', 'SP'),
#  ('콜', 'NNP'),
#  ('로이드', 'NNP'),
#  ('성', 'NNP'),
#  ('이산', 'NNP'),
#  ('화', 'NNP'),
#  ('규소', 'NNP'),
#  (',', 'SP'),
#  ('크로스', 'NNP'),
#  ('포', 'NNP'),
#  ('비도', 'NNP'),
#  ('ㄴ', 'JX'),
#  ('효능', 'NNG'),
#  ('/', 'SP'),
#  ('효과', 'NNG'),
#  ('다음', 'NNG'),
#  ('경우', 'NNG'),
#  ('의', 'JKG'),
#  ('비타민', 'NNP'),
#  ('B1', 'NNP'),
#  (',', 'SP'),
#  ('B2', 'NNP'),
#  (',', 'SP'),
#  ('B6', 'NNP'),
#  (',', 'SP'),
#  ('E', 'SL'),
#  (',', 'SP'),
#  ('C', 'SL'),
#  ('의', 'JKG'),
#  ('보급', 'NNG'),
#  (':', 'SP'),
#  ('육체', 'NNG'),
#  ('피로', 'NNP'),
#  (',', 'SP'),
#  ('임신', 'NNP'),
#  ('수', 'NNB'),
#  ('유기', 'NNP'),
#  (',', 'SP'),
#  ('병', 'NNG'),
#  ('중', 'NNB'),
#  ('및', 'MAJ'),
#  ('병', 'NNG'),
#  ('후', 'NNG'),
#  ('(', 'SS'),
#  ('병', 'NNG'),
#  ('을', 'JKO'),
#  ('앓', 'VV'),
#  ('는', 'ETM'),
#  ('동안', 'NNG'),
#  ('이나', 'JC'),
#  ('회복', 'NNG'),
#  ('후', 'NNG'),
#  (')', 'SS'),
#  ('의', 'JKG'),
#  ('체력', 'NNP'),
#  ('저하', 'NNP'),
#  ('시', 'NNB'),
#  (',', 'SP'),
#  ('노년기', 'NNG'),
#  ('-', 'SS'),
#  ('다음', 'NNG'),
#  ('증상', 'NNP'),
#  ('의', 'JKG'),
#  ('완화', 'NNG'),
#  (':', 'SP'),
#  ('신경통', 'NNG'),
#  (',', 'SP'),
#  ('근육통', 'NNP'),
#  (',', 'SP'),
#  ('관절통', 'NNP'),
#  ('(', 'SS'),
#  ('요통', 'NNP'),
#  (',', 'SP'),
#  ('어깨', 'NNG'),
#  ('결리', 'VV'),
#  ('ㅁ', 'ETN'),
#  ('등', 'NNB'),
#  (')', 'SS'),
#  ('-', 'SS'),
#  ('각기', 'MAG'),
#  ('-', 'SS'),
#  ('눈', 'NNG'),
#  ('의', 'JKG'),
#  ('피로', 'NNG'),
#  ('용법', 'NNG'),
#  ('/', 'SP'),
#  ('용량', 'NNP'),
#  ('성인', 'NNG'),
#  ('1', 'SN'),
#  ('회', 'NNB'),
#  ('1', 'SN'),
#  ('정', 'NNP'),
#  (',', 'SP'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('2', 'SN'),
#  ('회', 'NNB'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('포장', 'NNP'),
#  ('단위', 'NNP'),
#  ('10', 'SN'),
#  ('T', 'SL'),
#  (',', 'SP'),
#  ('100', 'SN'),
#  ('T', 'SL'),
#  (',', 'SP'),
#  ('150', 'SN'),
#  ('T', 'SL'),
#  (',', 'SP'),
#  ('300', 'SN'),
#  ('T', 'SW'),
#  ('1', 'SN'),
#  (')', 'SS'),
#  ('다음', 'NNG'),
#  ('과', 'JC'),
#  ('같', 'VA'),
#  ('은', 'ETM'),
#  ('사람', 'NNG'),
#  ('은', 'JX'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('을', 'JKO'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('말', 'NNG'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('1', 'SN'),
#  (')', 'SS'),
#  ('이', 'MM'),
#  ('약', 'MM'),
#  ('및', 'MAJ'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('에', 'JKB'),
#  ('포함', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('성분', 'NNG'),
#  ('에', 'JKB'),
#  ('과민반응', 'NNP'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('환자', 'NNG'),
#  ('(', 'SS'),
#  ('2', 'SN'),
#  (')', 'SS'),
#  ('만', 'NR'),
#  ('3', 'SN'),
#  ('개월', 'NNB'),
#  ('미만', 'NNG'),
#  ('의', 'JKG'),
#  ('젖먹이', 'NNG'),
#  ('(', 'SS'),
#  ('3', 'SN'),
#  (')', 'SS'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('은', 'JX'),
#  ('유당', 'NNP'),
#  ('을', 'JKO'),
#  ('함유', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VV'),
#  ('으므로', 'EC'),
#  (',', 'SP'),
#  ('가', 'VV'),
#  ('ㄹ락', 'EC'),
#  ('토', 'NNG'),
#  ('오스', 'NNP'),
#  ('불', 'XPN'),
#  ('내성', 'NNG'),
#  ('(', 'SS'),
#  ('galactose', 'SL'),
#  ('intolerance', 'SL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('Lapp', 'SL'),
#  ('유당', 'NNP'),
#  ('분해', 'NNG'),
#  ('효소', 'NNP'),
#  ('결핍증', 'NNG'),
#  ('(', 'SS'),
#  ('Lapp', 'SL'),
#  ('lactase', 'SL'),
#  ('deficiency', 'SL'),
#  (')', 'SS'),
#  ('또는', 'MAJ'),
#  ('포도', 'NNP'),
#  ('당', 'NNP'),
#  ('-', 'SS'),
#  ('가', 'VV'),
#  ('ㄹ락', 'EC'),
#  ('토', 'NNG'),
#  ('오스', 'NNP'),
#  ('흡수', 'NNP'),
#  ('장애', 'NNG'),
#  ('(', 'SS'),
#  ('glucose', 'SL'),
#  ('-', 'SS'),
#  ('galactose', 'SL'),
#  ('malabsorption', 'SL'),
#  (')', 'SS'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('유전', 'NNG'),
#  ('적', 'XSN'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETM'),
#  ('문제', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('환자', 'NNG'),
#  ('에게', 'JKB'),
#  ('는', 'JX'),
#  ('투여', 'NNG'),
#  ('하', 'XSV'),
#  ('면', 'EC'),
#  ('안', 'MAG'),
#  ('되', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('2', 'SN'),
#  (')', 'SS'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('을', 'JKO'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('동안', 'NNG'),
#  ('다음', 'NNG'),
#  ('의', 'JKG'),
#  ('약', 'NNG'),
#  ('을', 'JKO'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('지', 'EC'),
#  ('말', 'NNG'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('1', 'SN'),
#  (')', 'SS'),
#  ('레', 'NNP'),
#  ('보도', 'NNP'),
#  ('파', 'NNG'),
#  ('3', 'SN'),
#  (')', 'SS'),
#  ('다음', 'NNG'),
#  ('과', 'JC'),
#  ('같', 'VA'),
#  ('은', 'ETM'),
#  ('사람', 'NNG'),
#  ('(', 'SS'),
#  ('경우', 'NNP'),
#  (')', 'SS'),
#  ('은', 'JX'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('을', 'JKO'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('기', 'ETN'),
#  ('전', 'NNG'),
#  ('에', 'JKB'),
#  ('의사', 'NNG'),
#  (',', 'SP'),
#  ('치과의', 'NNP'),
#  ('사', 'NNG'),
#  (',', 'SP'),
#  ('약사', 'NNP'),
#  ('와', 'JC'),
#  ('상의', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('1', 'SN'),
#  (')', 'SS'),
#  ('의사', 'NNG'),
#  ('의', 'JKG'),
#  ('치료', 'NNG'),
#  ('를', 'JKO'),
#  ('받', 'VV'),
#  ('고', 'EC'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('환자', 'NNG'),
#  ('(', 'SS'),
#  ('2', 'SN'),
#  (')', 'SS'),
#  ('고', 'XPN'),
#  ('옥살산', 'NNP'),
#  ('뇨', 'NNG'),
#  ('증', 'NNG'),
#  ('환자', 'NNP'),
#  ('(', 'SS'),
#  ('hyperoxaluria', 'SL'),
#  (':', 'SP'),
#  ('요', 'MM'),
#  ('중', 'NNB'),
#  ('에', 'JKB'),
#  ('과', 'XPN'),
#  ('량', 'NNG'),
#  ('의', 'JKG'),
#  ('수산', 'NNG'),
#  ('염', 'NNP'),
#  ('이', 'JKS'),
#  ('배설', 'NNG'),
#  ('되', 'XSV'),
#  ('는', 'ETM'),
#  ('상태', 'NNG'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('3', 'SN'),
#  (')', 'SS'),
#  ('임부', 'NNG'),
#  ('및', 'MAJ'),
#  ('임신', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VV'),
#  ('을', 'ETM'),
#  ('가능', 'XR'),
#  ('성', 'XSN'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('여성', 'NNG'),
#  (',', 'SP'),
#  ('수', 'NNB'),
#  ('유부', 'NNP'),
#  (',', 'SP'),
#  ('미숙아', 'NNG'),
#  (',', 'SP'),
#  ('유아', 'NNP'),
#  ('(', 'SS'),
#  ('4', 'SN'),
#  (')', 'SS'),
#  ('통풍', 'NNP'),
#  ('환자', 'NNP'),
#  ('또는', 'MAJ'),
#  ('신장결석', 'NNP'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('환자', 'NNG'),
#  ('4', 'SN'),
#  (')', 'SS'),
#  ('다음', 'NNG'),
#  ('과', 'JC'),
#  ('같', 'VA'),
#  ('은', 'ETM'),
#  ('경우', 'NNG'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('의', 'JKG'),
#  ('복용', 'NNG'),
#  ('을', 'JKO'),
#  ('즉각', 'MAG'),
#  ('중지', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('의사', 'NNG'),
#  (',', 'SP'),
#  ('치과의', 'NNP'),
#  ('사', 'NNG'),
#  (',', 'SP'),
#  ('약사', 'NNP'),
#  ('와', 'JC'),
#  ('상의', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('상담', 'NNG'),
#  ('시', 'NNB'),
#  ('가능', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('한', 'MM'),
#  ('이', 'MM'),
#  ('첨부', 'NNP'),
#  ('문서', 'NNP'),
#  ('를', 'JKO'),
#  ('소지', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('1', 'SN'),
#  (')', 'SS'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('의', 'JKG'),
#  ('투여', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('다음', 'NNG'),
#  ('의', 'JKG'),
#  ('증상', 'NNG'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('을', 'ETM'),
#  ('경우', 'NNG'),
#  ('위', 'NNG'),
#  ('부', 'NNG'),
#  ('불쾌감', 'NNG'),
#  (',', 'SP'),
#  ('설사', 'NNP'),
#  (',', 'SP'),
#  ('변비', 'NNP'),
#  (',', 'SP'),
#  ('발진', 'NNP'),
#  (',', 'SP'),
#  ('발', 'NNG'),
#  ('적', 'XSN'),
#  (',', 'SP'),
#  ('구역', 'NNP'),
#  (',', 'SP'),
#  ('구토', 'NNP'),
#  (',', 'SP'),
#  ('묽', 'VA'),
#  ('은', 'ETM'),
#  ('변', 'NNP'),
#  (',', 'SP'),
#  ('구내염', 'NNP'),
#  ('(', 'SS'),
#  ('입안', 'NNG'),
#  ('염', 'NNP'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('식욕', 'NNP'),
#  ('부진', 'NNG'),
#  (',', 'SP'),
#  ('복부', 'NNG'),
#  ('팽만감', 'NNG'),
#  ('(', 'SS'),
#  ('2', 'SN'),
#  (')', 'SS'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('의', 'JKG'),
#  ('투여', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('생리', 'NNG'),
#  ('가', 'JKS'),
#  ('예정', 'NNG'),
#  ('보다', 'JKB'),
#  ('빠르', 'VA'),
#  ('아', 'EC'),
#  ('지', 'VX'),
#  ('거나', 'EC'),
#  ('양이', 'NNP'),
#  ('점점', 'MAG'),
#  ('많', 'VA'),
#  ('아', 'EC'),
#  ('지', 'VX'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('으며', 'EC'),
#  (',', 'SP'),
#  ('출혈', 'NNP'),
#  ('이', 'JKS'),
#  ('오래', 'MAG'),
#  ('지속', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('3', 'SN'),
#  (')', 'SS'),
#  ('에스트로겐', 'NNP'),
#  ('을', 'JKO'),
#  ('포함', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('경구', 'NNG'),
#  ('용', 'XSN'),
#  ('피임', 'NNP'),
#  ('제', 'XSN'),
#  ('를', 'JKO'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('여성', 'NNG'),
#  ('또는', 'MAJ'),
#  ('혈전', 'NNG'),
#  ('성', 'XSN'),
#  ('소인', 'NNP'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('환자', 'NNG'),
#  ('가', 'JKS'),
#  ('비타민 E', 'NNP'),
#  ('를', 'JKO'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('경우', 'NNG'),
#  ('혈전증', 'NNP'),
#  ('의', 'JKG'),
#  ('위험', 'NNG'),
#  ('이', 'JKS'),
#  ('증가', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('4', 'SN'),
#  (')', 'SS'),
#  ('장기간', 'NNG'),
#  ('고용량', 'NNG'),
#  ('을', 'JKO'),
#  ('투여', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('경우', 'NNG'),
#  ('내성', 'NNG'),
#  ('이', 'JKS'),
#  ('생기', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('5', 'SN'),
#  (')', 'SS'),
#  ('피리독신', 'NNP'),
#  ('을', 'JKO'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('500', 'SN'),
#  ('mg', 'SL'),
#  ('~', 'SO'),
#  ('2', 'SN'),
#  ('g', 'SL'),
#  ('의', 'JKG'),
#  ('용량', 'NNP'),
#  ('으로', 'JKB'),
#  ('장기간', 'NNG'),
#  ('복용', 'NNG'),
#  ('하', 'XSV'),
#  ('면', 'EC'),
#  ('감각', 'NNP'),
#  ('신경', 'NNP'),
#  ('병', 'NNG'),
#  ('또는', 'MAJ'),
#  ('신경', 'NNG'),
#  ('병', 'NNG'),
#  ('적', 'XSN'),
#  ('증상', 'NNP'),
#  ('(', 'SS'),
#  ('neuropathy', 'SL'),
#  (':', 'SP'),
#  ('말초', 'NNG'),
#  ('신경', 'NNG'),
#  ('계', 'XSN'),
#  ('의', 'JKG'),
#  ('기능', 'NNG'),
#  ('적', 'XSN'),
#  ('장애', 'NNG'),
#  ('또는', 'MAJ'),
#  ('병', 'NNG'),
#  ('적', 'XSN'),
#  ('변화', 'NNG'),
#  (')', 'SS'),
#  ('이', 'MM'),
#  ('나타나', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('6', 'SN'),
#  (')', 'SS'),
#  ('폴', 'NNP'),
#  ('산이', 'NNP'),
#  ('부족', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('환자', 'NNG'),
#  ('에게', 'JKB'),
#  ('비타민 B12', 'NNP'),
#  ('를', 'JKO'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('10', 'SN'),
#  ('μ', 'SW'),
#  ('g', 'SL'),
#  ('이상', 'NNG'),
#  ('투여', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('경우', 'NNG'),
#  ('혈액학', 'NNP'),
#  ('적', 'XSN'),
#  ('이상', 'NNG'),
#  ('반응', 'NNG'),
#  ('이', 'JKS'),
#  ('나타나', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  (')', 'SS'),
#  ('기타', 'NNG'),
#  ('이', 'MM'),
#  ('약', 'NNG'),
#  ('의', 'JKG'),
#  ('복용', 'NNG'),
#  ('시', 'NNB'),
#  ('주의', 'NNG'),
#  ('사항', 'NNG'),
#  ('(', 'SS'),
#  ('1', 'SN'),
#  (')', 'SS'),
#  ('정해진', 'NNP'),
#  ('용법', 'NNG'),
#  ('ㆍ', 'SP'),
#  ('용량', 'NNP'),
#  ('을', 'JKO'),
#  ('잘', 'MAG'),
#  ('지키', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('2', 'SN'),
#  (')', 'SS'),
#  ('각종', 'NNG'),
#  ('요', 'MM'),
#  ('검사', 'NNP'),
#  ('시', 'NNB'),
#  ('에', 'JKB'),
#  ('혈당', 'NNP'),
#  ('의', 'JKG'),
#  ('검출', 'NNG'),
#  ('을', 'JKO'),
#  ('방해', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('다', 'EC'),
#  ('(', 'SS'),
#  ('3', 'SN'),
#  (')', 'SS'),
#  ('요', 'NNG'),
#  ('를', 'JKO'),
#  ('황색', 'NNG'),
#  ('으로', 'JKB'),
#  ('변하', 'VV'),
#  ('게', 'EC'),
#  ('하', 'VV'),
#  ('아', 'EC'),
#  ('임상', 'NNG'),
#  ('검사', 'NNG'),
#  ('치', 'XSN'),
#  ('에', 'JKB'),
#  ('영향', 'NNG'),
#  ('을', 'JKO'),
#  ('주', 'VX'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('다', 'EC'),
#  ('6', 'SN'),
#  (')', 'SS'),
#  ('저', 'MM'),
#  ('장상', 'NNP'),
#  ('의', 'JKG'),
#  ('주의', 'NNG'),
#  ('사항', 'NNG'),
#  ('(', 'SS'),
#  ('1', 'SN'),
#  (')', 'SS'),
#  ('어린이', 'NNG'),
#  ('의', 'JKG'),
#  ('손', 'NNG'),
#  ('에', 'JKB'),
#  ('닿', 'VV'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('는', 'ETM'),
#  ('곳', 'NNG'),
#  ('에', 'JKB'),
#  ('보관', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('2', 'SN'),
#  (')', 'SS'),
#  ('직사광선', 'NNG'),
#  ('을', 'JKO'),
#  ('피하', 'VV'),
#  ('고', 'EC'),
#  ('되', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('한', 'MM'),
#  ('습기', 'NNG'),
#  ('가', 'JKS'),
#  ('적', 'VA'),
#  ('은', 'ETM'),
#  ('서늘', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('곳', 'NNG'),
#  ('에', 'JKB'),
#  ('밀폐', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('보관', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('(', 'SS'),
#  ('3', 'SN'),
#  (')', 'SS'),
#  ('오용', 'NNP'),
#  ('(', 'SS'),
#  ('잘못', 'MAG'),
#  ('사용', 'NNG'),
#  (')', 'SS'),
#  ('을', 'ETM'),
#  ('막', 'VV'),
#  ('고', 'EC'),
#  ('품질', 'NNP'),
#  ('의', 'JKG'),
#  ('보존', 'NNG'),
#  ('을', 'JKO'),
#  ('위하', 'VV'),
#  ('아', 'EC'),
#  ('다른', 'MM'),
#  ('용기', 'NNG'),
#  ('에', 'JKB'),
#  ('바꾸', 'VV'),
#  ('어', 'EC'),
#  ('넣', 'VV'),
#  ('지', 'EC'),
#  ('말', 'NNG'),
#  ('것', 'NNB'),
#  ('.', 'SF'),
#  ('<', 'SS'),
#  ('<', 'SS'),
#  ('https', 'SL'),
#  (':', 'SP'),
#  ('/', 'SP'),
#  ('/', 'SP'),
#  ('www', 'SL'),
#  ('.', 'SF'),
#  ('ildong', 'SL'),
#  ('.com', 'NNP'),
#  ('/', 'SP'),
#  ('kor', 'SL'),
#  ...]

# %% [markdown]
# ### 한나눔 파트
# - 딱봐도 구림

# %%
print(han.pos(text))
# Out:
# [('성분', 'N'), ('/', 'S'), ('함량', 'N'), ('원료약품', 'N'), ('및', 'M'), ('분량', 'N'), ('(', 'S'), ('1정', 'N'), ('중', 'N'), (')', 'S'), ('유효성분', 'N'), (':', 'S'), ('푸르설티아민', 'N'), ('(활성비타민B1)', 'N'), ('(', 'S'), ('KP', 'F'), (')', 'S'), ('50.', 'N'), ('0mg', 'N'), ('리보플라빈부티레이트', 'N'), ('(활성비타민B2)', 'N'), ('(', 'S'), ('KP', 'F'), (')', 'S'), ('2.5mg', 'N'), ('피리독살포스페이트수화물', 'N'), ('(활성비타민B6)', 'N'), ('(', 'S'), ('KP', 'F'), (')', 'S'), ('2.5mg', 'N'), ('히드록소코발라민아세트산염', 'N'), ('(활성비타민B12)', 'N'), ('(', 'S'), ('KP', 'F'), (')', 'S'), ('5.22㎍', 'N'), ('아스코르브산', 'N'), ('(비타민C)', 'N'), ('(직타용)(별규)(아스코르브산으로서70.', 'N'), ('0mg)', 'N'), ('72.', 'N'), ('2mg', 'N'), ('토코페롤아세테이트', 'N'), ('2배산', 'N'), ('(비타민E로서', 'N'), ('20', 'N'), ('IU', 'F'), (')', 'S'), ('(KP)(토코페롤아세테이트로서', 'N'), ('20.', 'N'), ('0mg)', 'N'), ('40.', 'N'), ('0mg', 'N'), ('첨가제(타르색소)', 'N'), (':', 'S'), ('적색40호,', 'N'), ('청색2호,', 'N'), ('황색203호', 'N'), ('첨가제(동물유래성분)', 'N'), (':', 'S'), ('유당수화물(소,', 'N'), ('우유', 'N'), (')', 'S'), ('기타', 'N'), ('첨가제', 'N'), (':', 'S'), ('미결정셀룰로오스,', 'N'), ('스테아르산마그네슘,', 'N'), ('오파드라', 'N'), ('이', 'J'), ('빨간색(OY-25014),', 'N'), ('오파드라', 'N'), ('이', 'J'), ('클리어', 'N'), ('(', 'S'), ('OY', 'F'), ('-', 'S'), ('S', 'F'), ('-', 'S'), ('29019', 'N'), ('),', 'S'), ('코포비돈,', 'N'), ('콜로이드성이산화규소,', 'N'), ('크로스포비돈', 'N'), ('효능', 'N'), ('/', 'S'), ('효과', 'N'), ('다음', 'N'), ('경우', 'N'), ('의', 'J'), ('비타민', 'N'), ('B1,', 'N'), ('B2,', 'N'), ('B6,', 'N'), ('E', 'F'), (',', 'S'), ('C', 'F'), ('의', 'J'), ('보급', 'N'), (':', 'S'), ('육체피', 'N'), ('로', 'J'), (',', 'S'), ('임신', 'N'), ('수유', 'N'), ('이', 'J'), ('기', 'E'), (',', 'S'), ('병중', 'N'), ('및', 'M'), ('병후(병', 'N'), ('을', 'J'), ('앓', 'P'), ('는', 'E'), ('동안', 'N'), ('이나', 'J'), ('회복', 'N'), ('후', 'N'), (')', 'S'), ('의', 'J'), ('체력저하', 'N'), ('시', 'X'), (',', 'S'), ('노년기', 'N'), ('-', 'S'), ('다음', 'N'), ('증상', 'N'), ('의', 'J'), ('완화', 'N'), (':', 'S'), ('신경통', 'N'), (',', 'S'), ('근육통', 'N'), (',', 'S'), ('관절통(요통,', 'N'), ('어깨결림', 'N'), ('등', 'N'), (')', 'S'), ('-', 'S'), ('각기', 'M'), ('-', 'S'), ('눈의피', 'N'), ('로', 'J'), ('용법', 'N'), ('/', 'S'), ('용량', 'N'), ('성', 'N'), ('이', 'J'), ('ㄴ', 'E'), ('1회', 'N'), ('1정', 'N'), (',', 'S'), ('1일', 'N'), ('2회', 'N'), ('복용', 'N'), ('하', 'X'), ('ㅂ니다', 'E'), ('.', 'S'), ('포장단위', 'N'), ('10T,', 'N'), ('100T,', 'N'), ('150T,', 'N'), ('300T', 'N'), ('1', 'N'), (')', 'S'), ('다음', 'N'), ('과', 'J'), ('같', 'P'), ('은', 'E'), ('사람', 'N'), ('은', 'J'), ('이', 'M'), ('약', 'N'), ('을', 'J'), ('복용', 'N'), ('하', 'X'), ('지', 'E'), ('말', 'P'), ('ㄹ', 'E'), ('것', 'N'), ('.', 'S'), ('(', 'S'), ('1', 'N'), (')', 'S'), ('이', 'M'), ('약', 'N'), ('및', 'M'), ('이', 'M'), ('약', 'N'), ('에', 'J'), ('포함', 'N'), ('되', 'X'), ('ㄴ', 'E'), ('성분', 'N'), ('에', 'J'), ('과민반응', 'N'), ('이', 'J'), ('있', 'P'), ('는', 'E'), ('환자', 'N'), ('(', 'S'), ('2', 'N'), (')', 'S'), ('말', 'P'), ('ㄴ', 'E'), ('3개월', 'N'), ('미만', 'N'), ('의', 'J'), ('젖먹이', 'N'), ('(', 'S'), ('3', 'N'), (')', 'S'), ('이', 'M'), ('약', 'N'), ('은', 'J'), ('유당', 'N'), ('을', 'J'), ('함유', 'N'), ('하고', 'J'), ('있', 'P'), ('으므로', 'E'), (',', 'S'), ('갈락토오스', 'N'), ('불내성(galactose', 'N'), ('intolerance', 'F'), ('),', 'S'), ('Lapp', 'F'), ('유당분해효소', 'N'), ('결핍증(Lapp', 'N'), ('lactase', 'F'), ('deficiency', 'F'), (')', 'S'), ('또는', 'M'), ('포도당-갈락토오스', 'N'), ('흡수장애(glucose-galactose', 'N'), ('malabsorption', 'F'), (')', 'S'), ('등', 'N'), ('의', 'J'), ('유전적', 'N'), ('이', 'J'), ('ㄴ', 'E'), ('문제', 'N'), ('가', 'J'), ('있', 'P'), ('는', 'E'), ('환자', 'N'), ('에게는', 'J'), ('투', 'N'), ('이', 'J'), ('어', 'E'), ('하', 'P'), ('면', 'E'), ('안', 'M'), ('되', 'P'), ('ㄴ다', 'E'), ('.', 'S'), ('2', 'N'), (')', 'S'), ('이', 'M'), ('약', 'N'), ('을', 'J'), ('복용', 'N'), ('하', 'X'), ('는', 'E'), ('동안', 'N'), ('다음', 'N'), ('의', 'J'), ('약', 'N'), ('을', 'J'), ('복용', 'N'), ('하', 'X'), ('지', 'E'), ('말', 'P'), ('ㄹ', 'E'), ('것', 'N'), ('.', 'S'), ('(', 'S'), ('1', 'N'), (')', 'S'), ('레보도파', 'N'), ('3', 'N'), (')', 'S'), ('다음', 'N'), ('과', 'J'), ('같', 'P'), ('은', 'E'), ('사람(경우)은', 'N'), ('이', 'M'), ('약', 'N'), ('을', 'J ...
