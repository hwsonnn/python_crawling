# %%
from konlpy.tag import *
import time

# %% [markdown]
# ### 오픈소스 형식 형태소 분석기 5가지
# - mecab 확인하고 다시.. 우분투가 잘안되서 패스
# - 한나눔은 너무 성능이 떨어져서 제외. 일단표기는 해둠
# - 카카오 형태소 분석기 카이를 제외한 이유는 사전 추가가 안된다.
#
# - 트위터 분석기, 코모란 두 가지를 중점

# %%
okt = Okt()
han = Hannanum()
komoran = Komoran()
ko = Kkma()

# %%
# 데이터 입수
text = open( '후시딘.txt' ).read()

# %% [markdown]
# #### 트위터 부분

# %%
# 트위터 morphs
okt_result = okt.morphs(text)
# 트위터 nouns 
okt_result1 = okt.nouns(text)
# 트위터 phrases
okt_result2 = okt.phrases(text)
# 트위터 pos 
okt_result3 = okt.pos(text)

# %%
# 트위터 분석기 
print(okt_result3)
# Out:
# [('<<', 'Punctuation'), ('동화약품', 'Noun'), (':', 'Punctuation'), ('http://www.dong-wha.co.kr/product/content.asp?t_idx=85&t_page=1&d=&b=20&s=23', 'URL'), ('>>', 'Punctuation'), ('\n\n', 'Foreign'), ('#', 'Punctuation'), ('효능', 'Noun'), (',', 'Punctuation'), ('효과', 'Noun'), ('\n', 'Foreign'), ('[', 'Punctuation'), ('후시', 'Noun'), ('딘', 'Noun'), ('연고', 'Noun'), ('(', 'Punctuation'), ('5', 'Number'), ('g', 'Alpha'), ('/', 'Punctuation'), ('4.5', 'Number'), ('g', 'Alpha'), ('/', 'Punctuation'), ('10', 'Number'), ('g', 'Alpha'), ('),', 'Punctuation'), ('후시', 'Noun'), ('딘겔', 'Noun'), (',', 'Punctuation'), ('후시', 'Noun'), ('딘', 'Noun'), ('크림', 'Noun'), (']', 'Punctuation'), ('\n', 'Foreign'), ('ㆍ', 'Foreign'), ('유효', 'Noun'), ('균종', 'Noun'), ('\n', 'Foreign'), ('포도', 'Noun'), ('구', 'Modifier'), ('균', 'Noun'), ('(', 'Punctuation'), ('포도', 'Noun'), ('알균', 'Noun'), ('),', 'Punctuation'), ('연쇄', 'Noun'), ('구', 'Modifier'), ('균', 'Noun'), (',', 'Punctuation'), ('코리', 'Noun'), ('네', 'Josa'), ('박테', 'Verb'), ('륨', 'Noun'), (',', 'Punctuation'), ('클로스', 'Noun'), ('트리', 'Noun'), ('듐', 'Noun'), ('\n', 'Foreign'), ('ㆍ', 'Foreign'), ('적응', 'Noun'), ('증', 'Noun'), ('\n', 'Foreign'), ('농피증', 'Noun'), ('(', 'Punctuation'), ('고름', 'Noun'), ('피부', 'Noun'), ('증', 'Noun'), (')(', 'Punctuation'), ('농가진', 'Noun'), ('(', 'Punctuation'), ('고름', 'Noun'), ('딱', 'Modifier'), ('지증', 'Noun'), ('),', 'Punctuation'), ('감염', 'Noun'), ('성', 'Modifier'), ('습진', 'Noun'), ('양', 'Suffix'), ('피부염', 'Noun'), (',', 'Punctuation'), ('심상', 'Noun'), ('성', 'Modifier'), ('여드름', 'Noun'), ('(', 'Punctuation'), ('보통', 'Noun'), ('여드름', 'Noun'), ('),', 'Punctuation'), ('모낭', 'Noun'), ('염', 'Noun'), (',', 'Punctuation'), ('종기', 'Noun'), ('및', 'Noun'), ('종기', 'Noun'), ('증', 'Noun'), (',', 'Punctuation'), ('화농', 'Noun'), ('(', 'Punctuation'), ('곪음', 'Noun'), (')', 'Punctuation'), ('성', 'Modifier'), ('한선', 'Noun'), ('염', 'Noun'), (',', 'Punctuation'), ('농가진', 'Noun'), ('(', 'Punctuation'), ('고름', 'Noun'), ('딱', 'Modifier'), ('지증', 'Noun'), (')', 'Punctuation'), ('성', 'Modifier'), ('습진', 'Noun'), ('),', 'Punctuation'), ('화상', 'Noun'), ('ㆍ', 'Foreign'), ('외상', 'Noun'), ('(', 'Punctuation'), ('상처', 'Noun'), (')', 'Punctuation'), ('ㆍ', 'Foreign'), ('봉합', 'Noun'), ('(', 'Punctuation'), ('꿰맴', 'Verb'), (')', 'Punctuation'), ('창', 'Noun'), ('ㆍ', 'Foreign'), ('식피창', 'Noun'), ('(', 'Punctuation'), ('피부', 'Noun'), ('이식', 'Noun'), ('후', 'Noun'), ('생긴', 'Verb'), ('상처', 'Noun'), (')', 'Punctuation'), ('에', 'Josa'), ('의한', 'Adjective'), ('2', 'Number'), ('차', 'Noun'), ('감염', 'Noun'), ('\n', 'Foreign'), ('(', 'Punctuation'), ('신제품', 'Noun'), (')', 'Punctuation'), ('후시', 'Noun'), ('딘', 'Noun'), ('연고', 'Noun'), ('4.5', 'Number'), ('g', 'Alpha'), ('은', 'Noun'), ('0.5', 'Number'), ('g', 'Alpha'), ('파우치', 'Noun'), ('/', 'Punctuation'), ('9', 'Number'), ('개입', 'Noun'), ('으로', 'Josa'), ('휴대', 'Noun'), ('가', 'Josa'), ('간편합니다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('[', 'Punctuation'), ('후시', 'Noun'), ('딘', 'Noun'), ('밴드', 'Noun'), ('첩', 'Noun'), ('부제', 'Noun'), (']', 'Punctuation'), ('\n', 'Foreign'), ('ㆍ', 'Foreign'), ('유효', 'Noun'), ('균종', 'Noun'), ('\n', 'Foreign'), ('포도', 'Noun'), ('구', 'Modifier'), ('균', 'Noun'), ('\n', 'Foreign'), ('ㆍ', 'Foreign'), ('적응', 'Noun'), ('증', 'Noun'), ('\n', 'Foreign'), ('농피증', 'Noun'), ('(', 'Punctuation'), ('농가진', 'Noun'), (',', 'Punctuation'), ('모낭', 'Noun'), ('염', 'Noun'), (',', 'Punctuation'), ('종기', 'Noun'), ('),', 'Punctuation'), ('화상', 'Noun'), ('ㆍ', 'Foreign'), ('외상', 'Noun'), ('ㆍ', 'Foreign'), ('봉', 'Noun'), ('합창', 'Noun'), ('ㆍ', 'Foreign'), ('식피창', 'Noun'), ('에', 'Josa'), ('의한', 'Adjective'), ('2', 'Number'), ('차', 'Noun'), ('감염', 'Noun'), ('\n', 'Foreign'), ('*', 'Punctuation'), ('농가진', 'Noun'), (':', 'Punctuation'), ('농포', 'Noun'), ('(', 'Punctuation'), ('膿疱', 'Foreign'), ('),', 'Punctuation'), ('가', 'Verb'), ('피', 'Noun'), ('(', 'Punctuation'), ('痂皮', 'Foreign'), (')', 'Punctuation'), ('를', 'Noun'), ('주요', 'Noun'), ('증세', 'Noun'), ('로', 'Josa') ...

# %% [markdown]
# ### 코모란 부분

# %%
komoran_result = komoran.nouns("\n".join([x for x in text.split("\n") if x]))
komoran_result1 = komoran.morphs("\n".join([x for x in text.split("\n") if x]))
komoran_result2 = komoran.pos("\n".join([x for x in text.split("\n") if x]))

# %%
# 코모란 
komoran_result2
# Out:
# [('<', 'SS'),
#  ('<', 'SS'),
#  ('동화약품', 'NNP'),
#  (':', 'SP'),
#  ('http', 'SL'),
#  (':', 'SP'),
#  ('/', 'SP'),
#  ('/', 'SP'),
#  ('www', 'SL'),
#  ('.', 'SF'),
#  ('dong', 'SL'),
#  ('-', 'SS'),
#  ('wha', 'SL'),
#  ('.co', 'NNP'),
#  ('.kr', 'NNP'),
#  ('/', 'SP'),
#  ('product', 'SL'),
#  ('/', 'SP'),
#  ('content', 'SL'),
#  ('.', 'SF'),
#  ('asp', 'SL'),
#  ('?', 'SF'),
#  ('t', 'SL'),
#  ('_', 'SW'),
#  ('idx', 'SL'),
#  ('=', 'SW'),
#  ('85', 'SN'),
#  ('&', 'SW'),
#  ('t', 'SL'),
#  ('_', 'SW'),
#  ('page', 'SL'),
#  ('=', 'SW'),
#  ('1', 'SN'),
#  ('&', 'SW'),
#  ('d', 'SL'),
#  ('=', 'SW'),
#  ('&', 'SW'),
#  ('b', 'SL'),
#  ('=', 'SW'),
#  ('20', 'SN'),
#  ('&', 'SW'),
#  ('s', 'SL'),
#  ('=', 'SW'),
#  ('23', 'SN'),
#  ('>', 'SS'),
#  ('>', 'SS'),
#  ('#', 'SW'),
#  ('효능', 'NNG'),
#  (',', 'SP'),
#  ('효과', 'NNG'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('연고', 'NNG'),
#  ('(', 'SS'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('/', 'SP'),
#  ('4', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('/', 'SP'),
#  ('10', 'SN'),
#  ('g', 'SL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('게', 'NNG'),
#  ('ㄹ', 'JKO'),
#  (',', 'SP'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('크림', 'NNP'),
#  (']', 'SS'),
#  ('ㆍ', 'SP'),
#  ('유효', 'NNG'),
#  ('균', 'NNG'),
#  ('종', 'NNG'),
#  ('포도', 'NNP'),
#  ('구균', 'NNG'),
#  ('(', 'SS'),
#  ('포도', 'NNP'),
#  ('알', 'NNP'),
#  ('균', 'NNG'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('연쇄', 'NNG'),
#  ('구균', 'NNG'),
#  (',', 'SP'),
#  ('코리네박테륨,', 'NA'),
#  ('클로스트리듐', 'NA'),
#  ('ㆍ', 'SP'),
#  ('적응', 'NNP'),
#  ('증', 'NNG'),
#  ('농', 'NNG'),
#  ('피', 'NNG'),
#  ('증', 'NNG'),
#  ('(', 'SS'),
#  ('고름', 'NNP'),
#  ('피부', 'NNP'),
#  ('증', 'NNG'),
#  (')', 'SS'),
#  ('(', 'SS'),
#  ('농가진', 'NNP'),
#  ('(', 'SS'),
#  ('고름', 'NNP'),
#  ('딱지', 'NNP'),
#  ('증', 'NNG'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('감염', 'NNP'),
#  ('성', 'NNP'),
#  ('습진', 'NNP'),
#  ('양', 'NNP'),
#  ('피부염', 'NNP'),
#  (',', 'SP'),
#  ('심상', 'NNG'),
#  ('성', 'NNP'),
#  ('여드름', 'NNP'),
#  ('(', 'SS'),
#  ('보통', 'NNP'),
#  ('여드름', 'NNP'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('모낭', 'NNP'),
#  ('염', 'NNP'),
#  (',', 'SP'),
#  ('종기', 'NNP'),
#  ('및', 'MAJ'),
#  ('종', 'NNG'),
#  ('기증', 'NNG'),
#  (',', 'SP'),
#  ('화', 'NNG'),
#  ('농', 'NNG'),
#  ('(', 'SS'),
#  ('곪', 'VV'),
#  ('음', 'ETN'),
#  (')', 'SS'),
#  ('성한', 'NNP'),
#  ('선', 'NNG'),
#  ('염', 'NNP'),
#  (',', 'SP'),
#  ('농가진', 'NNP'),
#  ('(', 'SS'),
#  ('고름', 'NNP'),
#  ('딱지', 'NNP'),
#  ('증', 'NNG'),
#  (')', 'SS'),
#  ('성', 'NNP'),
#  ('습진', 'NNP'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('화상', 'NNP'),
#  ('ㆍ', 'SP'),
#  ('외상', 'NNP'),
#  ('(', 'SS'),
#  ('상처', 'NNP'),
#  (')', 'SS'),
#  ('ㆍ', 'SP'),
#  ('봉합', 'NNG'),
#  ('(', 'SS'),
#  ('꿰매', 'VV'),
#  ('ㅁ', 'ETN'),
#  (')', 'SS'),
#  ('창', 'NNG'),
#  ('ㆍ', 'SP'),
#  ('식', 'NNG'),
#  ('피', 'NNG'),
#  ('창', 'NNG'),
#  ('(', 'SS'),
#  ('피부', 'NNP'),
#  ('이식', 'NNP'),
#  ('후', 'NNG'),
#  ('생기', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('상처', 'NNP'),
#  (')', 'SS'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('2', 'SN'),
#  ('차', 'NNB'),
#  ('감염', 'NNP'),
#  ('(', 'SS'),
#  ('신', 'XPN'),
#  ('제품', 'NNP'),
#  (')', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('연고', 'NNG'),
#  ('4', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('은', 'JX'),
#  ('0', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('파', 'NNP'),
#  ('우치', 'NNP'),
#  ('/', 'SP'),
#  ('9', 'SN'),
#  ('개입', 'NNP'),
#  ('으로', 'JKB'),
#  ('휴대', 'NNG'),
#  ('가', 'JKS'),
#  ('간편', 'XR'),
#  ('하', 'XSA'),
#  ('ㅂ니다', 'EF'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('밴드', 'NNP'),
#  ('첩', 'NNG'),
#  ('부제', 'NNP'),
#  (']', 'SS'),
#  ('ㆍ', 'SP'),
#  ('유효', 'NNG'),
#  ('균', 'NNG'),
#  ('종', 'NNG'),
#  ('포도', 'NNP'),
#  ('구균', 'NNG'),
#  ('ㆍ', 'SP'),
#  ('적응', 'NNP'),
#  ('증', 'NNG'),
#  ('농', 'NNG'),
#  ('피', 'NNG'),
#  ('증', 'NNG'),
#  ('(', 'SS'),
#  ('농가진', 'NNP'),
#  (',', 'SP'),
#  ('모낭', 'NNP'),
#  ('염', 'NNP'),
#  (',', 'SP'),
#  ('종기', 'NNP'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('화상', 'NNP'),
#  ('ㆍ', 'SP'),
#  ('외상', 'NNP'),
#  ('ㆍ', 'SP'),
#  ('봉', 'NNG'),
#  ('합창', 'NNP'),
#  ('ㆍ', 'SP'),
#  ('식', 'NNG'),
#  ('피', 'NNG'),
#  ('창', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('2', 'SN'),
#  ('차', 'NNB'),
#  ('감염', 'NNP'),
#  ('*', 'SW'),
#  ('농가진', 'NNP'),
#  (':', 'SP'),
#  ('농포', 'NNG'),
#  ('(', 'SS'),
#  ('膿疱', 'SH'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('가', 'XPN'),
#  ('피', 'NNG'),
#  ('(', 'SS'),
#  ('痂皮', 'SH'),
#  (')', 'SS'),
#  ('를', 'JKO'),
#  ('주요', 'XR'),
#  ('증세', 'NNG'),
#  ('로', 'JKB'),
#  ('하', 'VV'),
#  ('는', 'ETM'),
#  ('피부병', 'NNG'),
#  ('부스럼', 'NNG'),
#  (':', 'SP'),
#  ('피부', 'NNG'),
#  ('에', 'JKB'),
#  ('나', 'NP'),
#  ('는', 'JX'),
#  ('종기', 'NNP'),
#  ('를', 'JKO'),
#  ('통칭', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('용어', 'NNG'),
#  ('*', 'SW'),
#  ('화', 'NNG'),
#  ('농성', 'NNP'),
#  ('한', 'MM'),
#  ('선', 'NNB'),
#  ('염', 'NNP'),
#  (':', 'SP'),
#  ('땀샘', 'NNP'),
#  ('에', 'JKB'),
#  ('화', 'NNG'),
#  ('농', 'NNG'),
#  ('균', 'NNG'),
#  ('이', 'JKS'),
#  ('침입', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('염증', 'NNP'),
#  ('을', 'JKO'),
#  ('일으키', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('피부', 'NNP'),
#  ('의', 'JKG'),
#  ('깊', 'VA'),
#  ('은', 'ETM'),
#  ('곳', 'NNG'),
#  ('에', 'JKB'),
#  ('응어리', 'NNG'),
#  ('가', 'JKS'),
#  ('생기', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('상태', 'NNG'),
#  ('*', 'SW'),
#  ('봉', 'NNG'),
#  ('합창', 'NNP'),
#  (':', 'SP'),
#  ('외상', 'NNP'),
#  (',', 'SP'),
#  ('수술', 'NNP'),
#  ('후', 'NNG'),
#  ('상처', 'NNG'),
#  ('가', 'JKS'),
#  ('생기', 'VV'),
#  ('었', 'EP'),
#  ('을', 'ETM'),
#  ('때', 'NNG'),
#  ('꿰매', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('것', 'NNB'),
#  ('식', 'NNB'),
#  ('피', 'NNG'),
#  ('창', 'NNG'),
#  (':', 'SP'),
#  ('피부', 'NNP'),
#  ('이식', 'NNP'),
#  ('후', 'NNG'),
#  ('생기', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('상처', 'NNP'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('히드', 'NNP'),
#  ('로', 'JKB'),
#  ('크림', 'NNP'),
#  (']', 'SS'),
#  ('2', 'SN'),
#  ('차', 'NNB'),
#  ('세균', 'NNP'),
#  ('감염', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('습진', 'NNP'),
#  ('·', 'SP'),
#  ('피부염', 'NNP'),
#  ('군', 'NNB'),
#  (':', 'SP'),
#  ('아토피', 'NNP'),
#  ('피부염', 'NNP'),
#  (',', 'SP'),
#  ('접촉', 'NNG'),
#  ('피부염', 'NNP'),
#  (',', 'SP'),
#  ('알레르기', 'NNP'),
#  ('피부염', 'NNP'),
#  (',', 'SP'),
#  ('지루', 'NNP'),
#  ('피부염', 'NNP'),
#  ('*', 'SW'),
#  ('지루', 'XR'),
#  ('성', 'XSN'),
#  ('피부염', 'NNP'),
#  (':', 'SP'),
#  ('머리', 'NNG'),
#  ('·', 'SP'),
#  ('이마', 'NNP'),
#  ('·', 'SP'),
#  ('겨드랑이', 'NNP'),
#  ('등', 'NNB'),
#  ('피지', 'NNP'),
#  ('의', 'JKG'),
#  ('분비', 'NNG'),
#  ('가', 'JKS'),
#  ('많', 'VA'),
#  ('은', 'ETM'),
#  ('부위', 'NNG'),
#  ('에', 'JKB'),
#  ('잘', 'MAG'),
#  ('발생', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('피부염', 'NNP'),
#  ('#', 'SW'),
#  ('용법', 'NNG'),
#  (',', 'SP'),
#  ('용량', 'NNP'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('연고', 'NNG'),
#  ('(', 'SS'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('/', 'SP'),
#  ('4', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('/', 'SP'),
#  ('10', 'SN'),
#  ('g', 'SL'),
#  (')', 'SS'),
#  (']', 'SS'),
#  ('환부', 'NNG'),
#  ('(', 'SS'),
#  ('질환', 'NNG'),
#  ('부위', 'NNG'),
#  (')', 'SS'),
#  ('를', 'JKO'),
#  ('깨끗이', 'MAG'),
#  ('하', 'VV'),
#  ('고', 'EC'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('1', 'SN'),
#  ('~', 'SO'),
#  ('2', 'SN'),
#  ('회', 'NNB'),
#  ('적', 'NNG'),
#  ('당량', 'NNG'),
#  ('을', 'JKO'),
#  ('환부', 'NNG'),
#  ('(', 'SS'),
#  ('질환', 'NNG'),
#  ('부위', 'NNG'),
#  (')', 'SS'),
#  ('에', 'JKB'),
#  ('직접', 'MAG'),
#  ('바르', 'VA'),
#  ('거나', 'EC'),
#  ('무', 'XPN'),
#  ('균', 'NNG'),
#  ('거즈', 'NNP'),
#  ('에', 'JKB'),
#  ('넓', 'VA'),
#  ('게', 'EC'),
#  ('펴', 'VV'),
#  ('어', 'EC'),
#  ('바르', 'VV'),
#  ('아', 'EC'),
#  ('붙이', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('두껍', 'VA'),
#  ('게', 'EC'),
#  ('바르', 'VA'),
#  ('지', 'EC'),
#  ('않', 'VX'),
#  ('고', 'EC'),
#  ('보통', 'MAG'),
#  ('1', 'SN'),
#  ('주', 'NNB'),
#  ('정도', 'NNG'),
#  ('로', 'JKB'),
#  ('투여', 'NNG'),
#  ('기간', 'NNG'),
#  ('을', 'JKO'),
#  ('제한', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('게', 'NNG'),
#  ('ㄹ', 'JKO'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('3', 'SN'),
#  ('～', 'SO'),
#  ('4', 'SN'),
#  ('회', 'NNB'),
#  ('적', 'NNG'),
#  ('당량', 'NNG'),
#  ('을', 'JKO'),
#  ('환부', 'NNG'),
#  ('(', 'SS'),
#  ('질환', 'NNG'),
#  ('부위', 'NNG'),
#  (')', 'SS'),
#  ('에', 'JKB'),
#  ('부드럽', 'VA'),
#  ('게', 'EC'),
#  ('바르', 'VA'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('다만', 'MAJ'),
#  ('드레싱', 'NNP'),
#  ('을', 'JKO'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('경우', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('1', 'SN'),
#  ('～', 'SO'),
#  ('2', 'SN'),
#  ('회', 'NNB'),
#  ('정도', 'NNG'),
#  ('로', 'JKB'),
#  ('횟수', 'NNG'),
#  ('를', 'JKO'),
#  ('줄이', 'VV'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('바람직', 'XR'),
#  ('하', 'XSA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('크림', 'NNP'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('3', 'SN'),
#  ('~', 'SO'),
#  ('4', 'SN'),
#  ('회', 'NNB'),
#  ('적', 'NNG'),
#  ('당량', 'NNG'),
#  ('을', 'JKO'),
#  ('환부', 'NNG'),
#  ('(', 'SS'),
#  ('질환', 'NNG'),
#  ('부위', 'NNG'),
#  (')', 'SS'),
#  ('에', 'JKB'),
#  ('부드럽', 'VA'),
#  ('게', 'EC'),
#  ('바르', 'VA'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('다만', 'MAJ'),
#  ('드레싱', 'NNP'),
#  ('을', 'JKO'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('경우', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('1', 'SN'),
#  ('~', 'SO'),
#  ('2', 'SN'),
#  ('회', 'NNB'),
#  ('정도', 'NNG'),
#  ('로', 'JKB'),
#  ('횟수', 'NNG'),
#  ('를', 'JKO'),
#  ('줄이', 'VV'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('바람직', 'XR'),
#  ('하', 'XSA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('크림', 'NNP'),
#  ('제', 'XPN'),
#  ('형', 'NNG'),
#  ('으로', 'JKB'),
#  ('보습', 'NNG'),
#  ('효과', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VV'),
#  ('어', 'EC'),
#  ('거치', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('피부', 'NNG'),
#  ('에', 'JKB'),
#  ('효과', 'NNG'),
#  ('적', 'XSN'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('히드', 'NNP'),
#  ('로', 'JKB'),
#  ('크림', 'NNP'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('3', 'SN'),
#  ('∼', 'SO'),
#  ('4', 'SN'),
#  ('회', 'NNB'),
#  ('적', 'NNG'),
#  ('당량', 'NNG'),
#  ('을', 'JKO'),
#  ('환부', 'NNG'),
#  ('(', 'SS'),
#  ('질환', 'NNG'),
#  ('부위', 'NNG'),
#  (')', 'SS'),
#  ('에', 'JKB'),
#  ('부드럽', 'VA'),
#  ('게', 'EC'),
#  ('바르', 'VA'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('단', 'NNG'),
#  (',', 'SP'),
#  ('벗겨지', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('부위', 'NNG'),
#  ('는', 'JX'),
#  ('횟수', 'NNG'),
#  ('를', 'JKO'),
#  ('줄이', 'VV'),
#  ('어', 'EC'),
#  ('바르', 'VA'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('바람직', 'XR'),
#  ('하', 'XSA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('성분', 'NNG'),
#  ('과', 'JC'),
#  ('염증', 'NNP'),
#  ('완화', 'NNG'),
#  ('성분', 'NNG'),
#  ('이', 'JKS'),
#  ('복합', 'NNG'),
#  ('처방', 'NNG'),
#  ('되', 'XSV'),
#  ('어', 'EC'),
#  ('아토피', 'NNP'),
#  ('및', 'MAJ'),
#  ('염증', 'NNG'),
#  ('성', 'XSN'),
#  ('상처', 'NNG'),
#  ('에', 'JKB'),
#  ('효과', 'NNG'),
#  ('적', 'XSN'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('밴드', 'NNP'),
#  ('첩', 'NNG'),
#  ('부제', 'NNP'),
#  (']', 'SS'),
#  ('환부', 'NNG'),
#  ('(', 'SS'),
#  ('질환', 'NNG'),
#  ('부위', 'NNG'),
#  (')', 'SS'),
#  ('를', 'JKO'),
#  ('깨끗이', 'MAG'),
#  ('하', 'VV'),
#  ('고', 'EC'),
#  ('종이', 'NNG'),
#  ('를', 'JKO'),
#  ('떼', 'VV'),
#  ('어', 'EC'),
#  ('내', 'VX'),
#  ('ㄴ', 'ETM'),
#  ('후', 'NNG'),
#  ('1', 'SN'),
#  ('일', 'NNB'),
#  ('1', 'SN'),
#  ('매', 'NNB'),
#  ('환부', 'NNG'),
#  ('(', 'SS'),
#  ('질환', 'NNG'),
#  ('부위', 'NNG'),
#  (')', 'SS'),
#  ('에', 'JKB'),
#  ('직접', 'MAG'),
#  ('부착', 'NNG'),
#  ('시키', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('그', 'MM'),
#  ('위', 'NNG'),
#  ('에', 'JKB'),
#  ('적당', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('거즈', 'NNP'),
#  ('또는', 'MAJ'),
#  ('붕대', 'NNP'),
#  ('로', 'JKB'),
#  ('고정', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('하', 'NNG'),
#  ('이드', 'NNP'),
#  ('로', 'JKB'),
#  ('게', 'NNG'),
#  ('ㄹ', 'JKO'),
#  ('소재', 'NNG'),
#  ('가', 'JKS'),
#  ('습윤', 'NNG'),
#  ('환경', 'NNG'),
#  ('을', 'JKO'),
#  ('제공', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('상처', 'NNP'),
#  ('치료', 'NNG'),
#  ('촉진', 'NNP'),
#  ('및', 'MAJ'),
#  ('흉터', 'NNP'),
#  ('를', 'JKO'),
#  ('최소', 'NNG'),
#  ('화해', 'NNP'),
#  ('주', 'VX'),
#  ('ㅁ', 'ETN'),
#  ('#', 'SW'),
#  ('유효', 'NNG'),
#  ('성분', 'NNG'),
#  ('의', 'JKG'),
#  ('함량', 'NNG'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('연고', 'NNG'),
#  ('(', 'SS'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('/', 'SP'),
#  ('4', 'SN'),
#  ('.', 'SF'),
#  ('5', 'SN'),
#  ('g', 'SL'),
#  ('/', 'SP'),
#  ('10', 'SN'),
#  ('g', 'SL'),
#  (')', 'SS'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('g', 'SW'),
#  ('중', 'NNB'),
#  (':', 'SP'),
#  ('퓨시드산나트륨(Sodium', 'NA'),
#  ('fusidate', 'SL'),
#  (')', 'SS'),
#  ('...', 'SE'),
#  ('......', 'SE'),
#  ('......', 'SE'),
#  ('20', 'SN'),
#  ('mg', 'SL'),
#  ('(', 'SS'),
#  ('역가', 'NNG'),
#  (')', 'SS'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('게', 'NNG'),
#  ('ㄹ', 'JKO'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('g', 'SW'),
#  ('중', 'NNB'),
#  (':', 'SP'),
#  ('퓨시드산수화물(Fusidic', 'NA'),
#  ('acid', 'SL'),
#  ('hydrate', 'SL'),
#  (')', 'SS'),
#  ('......', 'SE'),
#  ('.', 'SF'),
#  ('......', 'SE'),
#  ('.', 'SF'),
#  ('20', 'SN'),
#  ('mg', 'SL'),
#  ('(', 'SS'),
#  ('역가', 'NNG'),
#  (')', 'SS'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('크림', 'NNP'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('g', 'SW'),
#  ('중', 'NNB'),
#  (':', 'SP'),
#  ('퓨시드산수화물(Fusidic', 'NA'),
#  ('acid', 'SL'),
#  ('hydrate', 'SL'),
#  (')', 'SS'),
#  ('...', 'SE'),
#  ('......', 'SE'),
#  ('.', 'SF'),
#  ('20', 'SN'),
#  ('mg', 'SL'),
#  ('(', 'SS'),
#  ('역가', 'NNG'),
#  (')', 'SS'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('히드', 'NNP'),
#  ('로', 'JKB'),
#  ('크림', 'NNP'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('g', 'SW'),
#  ('중', 'NNB'),
#  (':', 'SP'),
#  ('퓨시드산수화물(Fusidic', 'NA'),
#  ('acid', 'SL'),
#  ('hydrate', 'SL'),
#  (')', 'SS'),
#  ('...', 'SE'),
#  ('......', 'SE'),
#  ('......', 'SE'),
#  ('......', 'SE'),
#  ('......', 'SE'),
#  ('20', 'SN'),
#  ('mg', 'SL'),
#  ('(', 'SS'),
#  ('역가', 'NNG'),
#  (')', 'SS'),
#  ('히드', 'NNP'),
#  ('로코', 'NNP'),
#  ('르', 'NNG'),
#  ('티', 'NNG'),
#  ('손', 'NNP'),
#  ('아세테이트', 'NNP'),
#  ('(', 'SS'),
#  ('Hydrocortisone', 'SL'),
#  ('acetate', 'SL'),
#  (')', 'SS'),
#  ('......', 'SE'),
#  ('.', 'SF'),
#  ('.', 'SF'),
#  ('10', 'SN'),
#  ('mg', 'SL'),
#  ('[', 'SS'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('밴드', 'NNP'),
#  ('첩', 'NNG'),
#  ('부제', 'NNP'),
#  (']', 'SS'),
#  ('1', 'SN'),
#  ('매', 'NNB'),
#  ('중', 'NNB'),
#  (':', 'SP'),
#  ('일반', 'NNG'),
#  ('형', 'XSN'),
#  (':', 'SP'),
#  ('퓨시드산나트륨(Sodium', 'NA'),
#  ('fusidate', 'SL'),
#  (')', 'SS'),
#  ('....', 'SE'),
#  ('.', 'SF'),
#  ('0', 'SN'),
#  ('.', 'SF'),
#  ('70', 'SN'),
#  ('mg', 'SL'),
#  ('(', 'SS'),
#  ('역가', 'NNG'),
#  ('로서', 'JKB'),
#  ('0', 'SN'),
#  ('.', 'SF'),
#  ('67', 'SN'),
#  ('mg', 'SL'),
#  (')', 'SS'),
#  ('대형', 'NNG'),
#  (':', 'SP'),
#  ('퓨시드산나트륨(Sodium', 'NA'),
#  ('fusidate', 'SL'),
#  (')', 'SS'),
#  ('....', 'SE'),
#  ('.', 'SF'),
#  ('1', 'SN'),
#  ('.', 'SF'),
#  ('81', 'SN'),
#  ('mg', 'SL'),
#  ('(', 'SS'),
#  ('역가', 'NNG'),
#  ('로서', 'JKB'),
#  ('1', 'SN'),
#  ('.', 'SF'),
#  ('73', 'SN'),
#  ('mg', 'SL'),
#  (')', 'SS'),
#  ('<', 'SS'),
#  ('<', 'SS'),
#  ('네이버', 'NNP'),
#  ('>', 'SS'),
#  ('>', 'SS'),
#  ('<', 'SS'),
#  ('<', 'SS'),
#  ('https', 'SL'),
#  (':', 'SP'),
#  ('/', 'SP'),
#  ('/', 'SP'),
#  ('blog', 'SL'),
#  ('.', 'SF'),
#  ('naver', 'SL'),
#  ('.com', 'NNP'),
#  ('/', 'SP'),
#  ('tymelong', 'SL'),
#  ('/', 'SP'),
#  ('221543421805', 'SN'),
#  ('>', 'SS'),
#  ('>', 'SS'),
#  ('여드름', 'NNP'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('모낭', 'NNP'),
#  ('염', 'NNP'),
#  ('항생제', 'NNG'),
#  ('연고', 'NNG'),
#  ('효과', 'NNG'),
#  ('뺨치', 'VV'),
#  ('ㅁ', 'ETN'),
#  ('하지만', 'MAJ'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('은', 'JX'),
#  ('‘퓨시드', 'NA'),
#  ('나트륨', 'NNP'),
#  ('’', 'SS'),
#  ('이', 'VCP'),
#  ('라는', 'ETM'),
#  ('항생', 'NNG'),
#  ('물질', 'NNG'),
#  ('이', 'JKS'),
#  ('주', 'MM'),
#  ('성분', 'NNG'),
#  ('으로', 'JKB'),
#  ('세균', 'NNP'),
#  ('증식', 'NNG'),
#  ('을', 'JKO'),
#  ('막', 'VV'),
#  ('을', 'ETM'),
#  ('수', 'NNB'),
#  ('는', 'JX'),
#  ('있', 'VV'),
#  ('지만', 'EC'),
#  ('저', 'MM'),
#  ('같', 'VA'),
#  ('은', 'ETM'),
#  ('면포', 'NNG'),
#  ('성', 'XSN'),
#  ('여드름', 'NNP'),
#  ('이나', 'JC'),
#  ('결정', 'NNG'),
#  ('낭', 'NNG'),
#  ('종', 'NNG'),
#  ('같', 'VA'),
#  ('은', 'ETM'),
#  ('여드름', 'NNP'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('효과', 'NNG'),
#  ('를', 'JKO'),
#  ('보', 'VV'),
#  ('기', 'ETN'),
#  ('가', 'JKS'),
#  ('힘들', 'VA'),
#  ('다고', 'EC'),
#  ('하네요..ㅠ', 'NA'),
#  ('게다가', 'MAG'),
#  ('후시', 'NNP'),
#  ('딘', 'NNP'),
#  ('은', 'JX'),
#  ('상처', 'NNP'),
#  ('치료', 'NNG'),
#  ('에', 'JKB'),
#  ('특화', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('항생제', 'NNG'),
#  ('연고', 'NNG'),
#  ('이', 'VCP'),
#  ...]

# %% [markdown]
# ### 한나눔 파트
# - 딱봐도 구림

# %%
print(han.pos(text))
# Out:
# [('<<', 'S'), ('동화약품', 'N'), (':', 'S'), ('http', 'F'), ('://', 'S'), ('www', 'F'), ('.', 'S'), ('dong', 'F'), ('-', 'S'), ('wha', 'F'), ('.', 'S'), ('co', 'F'), ('.', 'S'), ('kr', 'F'), ('/', 'S'), ('product', 'F'), ('/', 'S'), ('content', 'F'), ('.', 'S'), ('asp', 'F'), ('?', 'S'), ('t_idx=85&t_page=1&d=&b=20&s=23', 'N'), ('>>', 'S'), ('#', 'N'), ('효능', 'N'), (',', 'S'), ('효과', 'N'), ('[후시딘연고(5g', '4'), ('.', 'N'), ('5g', '10g'), ('),', 'N'), ('후시딘겔,', 'N'), ('후시딘크', 'N'), ('이', 'J'), ('리ㅁ', 'E'), (']', 'S'), ('ㆍ유효균종', 'N'), ('포도구균(포도알균),', 'N'), ('연쇄구균,', 'N'), ('코리네박테륨,', 'N'), ('클로스트리듐', 'N'), ('ㆍ적응증', 'N'), ('농피증(고름피부증)(농가진(고름딱지증),', 'N'), ('감염성습진양피부염,', 'N'), ('심상성여드름(보통여드름),', 'N'), ('모낭염,', 'N'), ('종기', 'N'), ('및', 'M'), ('종기증', 'N'), (',', 'S'), ('화농(곪음)성한선염', 'N'), (',', 'S'), ('농가진(고름딱지증)성습진),', 'N'), ('화상ㆍ외상(상처)ㆍ봉합(꿰맴)창ㆍ식피창(피부이식', 'N'), ('후', 'N'), ('생기', 'P'), ('ㄴ', 'E'), ('상처', 'N'), (')', 'S'), ('에', 'J'), ('의하', 'P'), ('ㄴ', 'E'), ('2차', 'N'), ('감염', 'N'), ('(', 'S'), ('신제품', 'N'), (')', 'S'), ('후시딘연고', 'N'), ('4.5g', 'N'), ('은', 'J'), ('0.', 'N'), ('5g파우치', '9개입'), ('/N+으로', 'J'), ('휴대', 'N'), ('가', 'J'), ('간편', 'N'), ('하', 'X'), ('ㅂ니다', 'E'), ('.', 'S'), ('[후시딘밴드', 'N'), ('첩부제', 'N'), (']', 'S'), ('ㆍ유효균종', 'N'), ('포도구균', 'N'), ('ㆍ적응증', 'N'), ('농피증(농가진,', 'N'), ('모낭염,', 'N'), ('종기', 'N'), ('),', 'S'), ('화상ㆍ외상ㆍ봉합창ㆍ식피창', 'N'), ('에', 'J'), ('의하', 'P'), ('ㄴ', 'E'), ('2차', 'N'), ('감염', 'N'), ('*', 'S'), ('농가진', 'N'), (':', 'S'), ('농포(膿疱),', 'N'), ('가피(痂皮)', 'N'), ('를', 'J'), ('주요', 'N'), ('증세', 'N'), ('로', 'J'), ('하', 'P'), ('는', 'E'), ('피부병부스럼', 'N'), (':', 'S'), ('피부', 'N'), ('에', 'J'), ('나', 'N'), ('는', 'J'), ('종기', 'N'), ('를', 'J'), ('통칭', 'N'), ('하', 'X'), ('는', 'E'), ('용어', 'N'), ('*', 'S'), ('화농성', 'N'), ('한선염', 'N'), (':', 'S'), ('땀샘', 'N'), ('에', 'J'), ('화농균', 'N'), ('이', 'J'), ('침입', 'N'), ('하', 'X'), ('어', 'E'), ('염증', 'N'), ('을', 'J'), ('일으키', 'P'), ('고', 'E'), (',', 'S'), ('피부', 'N'), ('의', 'J'), ('깊', 'P'), ('은', 'E'), ('곳', 'N'), ('에', 'J'), ('응어리', 'N'), ('가', 'J'), ('생기', 'P'), ('ㄴ', 'E'), ('상태', 'N'), ('*', 'S'), ('봉합창', 'N'), (':', 'S'), ('외상', 'N'), (',', 'S'), ('수술', 'N'), ('후', 'N'), ('상처', 'N'), ('가', 'J'), ('생기', 'P'), ('었을', 'E'), ('때', 'N'), ('꿰매', 'P'), ('ㄴ', 'E'), ('것식피창', 'N'), (':', 'S'), ('피부', 'N'), ('이식후', 'N'), ('생기', 'P'), ('ㄴ', 'E'), ('상처', 'N'), ('[후시딘', 'N'), ('히드', 'N'), ('로', 'J'), ('크림', 'N'), (']', 'S'), ('2차', 'N'), ('세균', 'N'), ('감염', 'N'), ('되', 'X'), ('ㄴ', 'E'), ('습진·피부염군', 'N'), (':', 'S'), ('아토피피부염,', 'N'), ('접촉피부염', 'N'), (',', 'S'), ('알레르기피부염', 'N'), (',', 'S'), ('지루피부염', 'N'), ('*', 'S'), ('지루성', 'N'), ('피부염', 'N'), (':', 'S'), ('머리', 'N'), ('·', 'S'), ('이마', 'N'), ('·', 'S'), ('겨드랑', 'N'), ('이', 'J'), ('등', 'N'), ('피지', 'N'), ('의', 'J'), ('분비', 'N'), ('가', 'J'), ('많', 'P'), ('은', 'E'), ('부위', 'N'), ('에', 'J'), ('잘', 'M'), ('발생', 'N'), ('하', 'X'), ('는', 'E'), ('피부염', 'N'), ('#', 'N'), ('용법', 'N'), (',', 'S'), ('용량', 'N'), ('[후시딘연고(5g', '4'), ('.', 'N'), ('5g', '10g'), ('/N+)]', 'S'), ('환부(질환', 'N'), ('부위', 'N'), (')', 'S'), ('를', 'J'), ('깨끗', 'N'), ('이', 'J'), ('하', 'P'), ('고', 'E'), ('1일', 'N'), ('1', 'N'), ('~', 'S'), ('2회', 'N'), ('적당량', 'N'), ('을', 'J'), ('환부(질환', 'N'), ('부위', 'N'), (')', 'S'), ('에', 'J'), ('직접', 'M'), ('바르', 'P'), ('거나', 'E'), ('무균거즈', 'N'), ('에', 'J'), ('넓', 'P'), ('게', 'E'), ('펴발라', 'N'), ('붙이', 'P'), ('ㄴ다', 'E'), ('.', 'S'), ('두껍', 'P'), ('게', 'E'), ('바르', 'P'), ('지', 'E'), ('않', 'P'), ('고', 'E'), ('보통', 'M'), ('1주', 'N'), ('정도', 'N'), ('로', 'J'), ('투여기간', 'N'), ('을', 'J'), ('제한', 'N'), ('하', 'X'), ('ㄴ다', 'E'), ('.', 'S'), ('[후시딘겔', 'N'), (']', 'S'), ('1일', 'N'), ('3～4회', 'N'), ('적당량', 'N'), ('을', 'J'), ('환부(질환', 'N'), ('부위', 'N'), (')', 'S'), ('에', 'J'), ('부드럽', 'P'), ('게', 'E'), ('바르', 'P'), ('ㄴ다', 'E'), ('.', 'S'), ('다만', 'M'), ('드레싱', 'N'), ('을', 'J'), ('하', 'P'), ('ㄹ', 'E'), ('경우', 'N'), ('에는', 'J'), ('1일', 'N'), ('1～2회', 'N'), ('정도', 'N'), ('로', 'J'), ('횟수', 'N'), ('를', 'J'), ('줄', 'N'), ('이', 'J'), ('는', 'E'), ('것', 'N'), ('이', 'J'), ...
